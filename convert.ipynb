# %% [markdown]
# need to install ffmpeg and add the path to your environment
#
# ``` sh
# https://www.gyan.dev/ffmpeg/builds/#release-builds
# ```
# ``` sh
# pip install ffmpeg-python
# ```

# %%
# !pip install ffmpeg-python
# Out:
# Collecting ffmpeg-python
#   Using cached ffmpeg_python-0.2.0-py3-none-any.whl.metadata (1.7 kB)
# Collecting future (from ffmpeg-python)
#   Using cached future-1.0.0-py3-none-any.whl.metadata (4.0 kB)
# Using cached ffmpeg_python-0.2.0-py3-none-any.whl (25 kB)
# Using cached future-1.0.0-py3-none-any.whl (491 kB)
# Installing collected packages: future, ffmpeg-python
# Successfully installed ffmpeg-python-0.2.0 future-1.0.0

# %%
# Convert videos to MP4 using FFmpeg 

import os
import subprocess

def is_ffmpeg_installed():
    try:
        subprocess.run(["ffmpeg", "-version"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL, check=True)
        return True
    except FileNotFoundError:
        return False

def convert_videos_to_mp4(input_folder, output_folder):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    for filename in os.listdir(input_folder):
        input_path = os.path.join(input_folder, filename)
        output_path = os.path.join(output_folder, os.path.splitext(filename)[0] + ".mp4")
        
        if os.path.isfile(input_path):
            if os.path.exists(output_path):
                print(f"Skipping: {filename} (already converted)")
                continue
            
            if filename.lower().endswith(".mp4"):
                try:
                    os.rename(input_path, output_path)
                    print(f"Copied: {filename} -> {output_path}")
                except Exception as e:
                    print(f"Error moving {filename}: {e}")
            else:
                # command = [
                #     "ffmpeg", "-hwaccel", "cuda", "-i", input_path,
                #     "-c:v", "h264_nvenc", "-preset", "fast", "-b:v", "5000k",
                #     "-pix_fmt", "yuv420p",
                #     "-c:a", "aac", "-b:a", "128k",
                #     output_path
                # ]
                
                command = [
                    "ffmpeg", "-hwaccel", "cuda", "-i", input_path,
                    "-c:v", "copy",  # Copy video without re-encoding
                    "-c:a", "copy",  # Copy audio without re-encoding
                    "-movflags", "+faststart",  # Optimize MP4 for streaming
                    output_path
                ]
                
                try:
                    subprocess.run(command, stdout=subprocess.DEVNULL, stderr=subprocess.PIPE, check=True)
                    print(f"Converted: {filename} -> {output_path}")
                except FileNotFoundError:
                    print("Error: FFmpeg is not installed or not in system PATH.")
                except subprocess.CalledProcessError as e:
                    print(f"Error converting {filename}: {e.stderr.decode(errors='ignore')}")
                except Exception as e:
                    print(f"Unexpected error processing {filename}: {e}")

if __name__ == "__main__":
    base_input_folder = "Recordings" 
    base_output_folder = "converted_videos" 
    
    if not os.path.exists(base_input_folder):
        print(f"Error: Input folder {base_input_folder} does not exist.")
    else:
        subfolders = [os.path.join(base_input_folder, d) for d in os.listdir(base_input_folder) if os.path.isdir(os.path.join(base_input_folder, d))]
        
        if subfolders:
            for input_folder in subfolders:
                relative_subfolder = os.path.relpath(input_folder, base_input_folder)
                output_folder = os.path.join(base_output_folder, relative_subfolder)
                convert_videos_to_mp4(input_folder, output_folder)
        else:
            convert_videos_to_mp4(base_input_folder, base_output_folder)
# Out:
# Skipping: IMG_4917.MOV (already converted)
# Skipping: IMG_4918-001.MOV (already converted)
# Copied: Part1.mp4 -> converted_videos\Part1.mp4
# Skipping: Part2-003.mp4 (already converted)
# Skipping: Recording from 2025-03-03 09-11-03.688254.webm (already converted)
# Skipping: Recording from 2025-03-03 10-51-23.391532.webm (already converted)
# Skipping: WIN_20250303_09_11_30_Pro.mp4 (already converted)
# Skipping: WIN_20250303_09_11_53_Pro.mp4 (already converted)
# Skipping: WIN_20250303_09_16_32_Pro.mp4 (already converted)
# Skipping: WIN_20250303_09_18_49_Pro.mp4 (already converted)
# Skipping: WIN_20250303_09_19_13_Pro-002.mp4 (already converted)
# Skipping: WIN_20250303_09_34_26_Pro(1)-011.mp4 (already converted)
# Skipping: WIN_20250303_09_34_26_Pro-012.mp4 (already converted)
# Skipping: WIN_20250303_10_47_26_Pro.mp4 (already converted)
# Skipping: WIN_20250303_10_53_26_Pro(1)-009.mp4 (already converted)
# Skipping: WIN_20250303_10_53_26_Pro-010.mp4 (already converted)
# Skipping: WIN_20250303_10_53_46_Pro.mp4 (already converted)
# Skipping: WIN_20250303_10_54_21_Pro-008.mp4 (already converted)
# Skipping: WIN_20250303_10_55_18_Pro.mp4 (already converted)
# Skipping: WIN_20250303_10_56_36_Pro-001.mp4 (already converted)
# Skipping: WIN_20250303_10_56_37_Pro-006.mp4 (already converted)
# Skipping: WIN_20250303_10_59_21_Pro.mp4 (already converted)
# Skipping: WIN_20250303_11_00_39_Pro.mp4 (already converted)
# Skipping: WIN_20250303_11_11_38_Pro.mp4 (already converted)
# Skipping: WIN_20250303_11_19_03_Pro.mp4 (already converted)
# Skipping: WIN_20250303_11_39_36_Pro-005.mp4 (already converted)

# %%
# Reduce video size using FFmpeg

import os
import subprocess

def reduce_video_size(input_folder, output_folder):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    for filename in os.listdir(input_folder):
        input_path = os.path.join(input_folder, filename)
        if os.path.isfile(input_path) and filename.lower().endswith(".mp4"):
            output_path = os.path.join(output_folder, filename)
            
            if os.path.exists(output_path):
                print(f"Skipping: {filename} already exists in {output_folder}")
                continue
            
            # command = [
            #     "ffmpeg", "-y", "-hwaccel", "cuda", "-hwaccel_output_format", "cuda", "-i", input_path,
            #     "-c:v", "hevc_nvenc", "-preset", "slow", "-b:v", "200k", 
            #     "-maxrate", "200k", "-bufsize", "400k", "-cq", "35", 
            #     # "-c:a", "aac", "-b:a", "64k", # Reduce audio bitrate
            #     "-an", # Disable audio
            #     output_path
            # ]
            
            command = [
                "ffmpeg", "-y", "-hwaccel", "cuda", "-hwaccel_output_format", "cuda", "-i", input_path,
                "-c:v", "hevc_nvenc", "-preset", "slow", "-cq", "28",  # Lower CQ = better quality (0-51, lower is better)
                "-b:v", "0",  # Ignore bitrate limit, use only CQ for better compression
                "-an",  # Disable audio
                output_path
            ]

            
            try:
                subprocess.run(command, stdout=subprocess.DEVNULL, stderr=subprocess.PIPE, check=True)
                print(f"Reduced size: {filename} -> {output_path}")
            except FileNotFoundError:
                print("Error: FFmpeg is not installed or not in system PATH.")
            except subprocess.CalledProcessError as e:
                print(f"Error reducing size of {filename}: {e.stderr.decode(errors='ignore')}")
            except Exception as e:
                print(f"Unexpected error processing {filename}: {e}")

if __name__ == "__main__":
    base_input_folder = "D:\Recordings\converted_videos - Copy" 
    base_output_folder = "reduced_videos2" 
    
    if not os.path.exists(base_input_folder):
        print(f"Error: Input folder {base_input_folder} does not exist.")
    else:
        subfolders = [os.path.join(base_input_folder, d) for d in os.listdir(base_input_folder) if os.path.isdir(os.path.join(base_input_folder, d))]
        
        if subfolders:
            for input_folder in subfolders:
                relative_subfolder = os.path.relpath(input_folder, base_input_folder)
                output_folder = os.path.join(base_output_folder, relative_subfolder)
                reduce_video_size(input_folder, output_folder)
        reduce_video_size(base_input_folder, base_output_folder)
# Out:
# Skipping: Part1.mp4 already exists in reduced_videos2
# Skipping: Part2-003.mp4 already exists in reduced_videos2
# Skipping: Recording from 2025-03-03 09-11-03.688254.mp4 already exists in reduced_videos2
# Skipping: Recording from 2025-03-03 10-51-23.391532.mp4 already exists in reduced_videos2
# Skipping: WIN_20250303_09_11_30_Pro.mp4 already exists in reduced_videos2
# Skipping: WIN_20250303_09_11_53_Pro.mp4 already exists in reduced_videos2
# Skipping: WIN_20250303_09_16_32_Pro.mp4 already exists in reduced_videos2
# Skipping: WIN_20250303_09_18_49_Pro.mp4 already exists in reduced_videos2
# Skipping: WIN_20250303_09_19_13_Pro-002.mp4 already exists in reduced_videos2
# Skipping: WIN_20250303_09_34_26_Pro(1)-011.mp4 already exists in reduced_videos2
# Skipping: WIN_20250303_09_34_26_Pro-012.mp4 already exists in reduced_videos2
# Skipping: WIN_20250303_10_47_26_Pro.mp4 already exists in reduced_videos2
# Skipping: WIN_20250303_10_47_36_Pro.mp4 already exists in reduced_videos2
# Skipping: WIN_20250303_10_47_46_Pro.mp4 already exists in reduced_videos2
# Skipping: WIN_20250303_10_53_26_Pro(1)-009.mp4 already exists in reduced_videos2
# Skipping: WIN_20250303_10_53_26_Pro-010.mp4 already exists in reduced_videos2
# Skipping: WIN_20250303_10_53_46_Pro.mp4 already exists in reduced_videos2
# Skipping: WIN_20250303_10_54_21_Pro-008.mp4 already exists in reduced_videos2
# Skipping: WIN_20250303_10_55_18_Pro.mp4 already exists in reduced_videos2
# Skipping: WIN_20250303_10_56_36_Pro-001.mp4 already exists in reduced_videos2
# Skipping: WIN_20250303_10_56_37_Pro-006.mp4 already exists in reduced_videos2
# Reduced size: WIN_20250303_10_57_32_Pro.mp4 -> reduced_videos2\WIN_20250303_10_57_32_Pro.mp4
# Skipping: WIN_20250303_10_59_21_Pro.mp4 already exists in reduced_videos2
# Skipping: WIN_20250303_11_00_39_Pro.mp4 already exists in reduced_videos2
# Skipping: WIN_20250303_11_11_38_Pro.mp4 already exists in reduced_videos2
# Skipping: WIN_20250303_11_19_03_Pro.mp4 already exists in reduced_videos2
# Skipping: WIN_20250303_11_39_36_Pro-005.mp4 already exists in reduced_videos2

# %%
# Rename videos in a folder
# Warning: This script will rename all videos in the folder to "Video 01.mp4", "Video 02.mp
# The original filenames will be lost
# Make sure to backup the original files before running this script

import os

def rename_videos(folder_path):
    videos = [f for f in os.listdir(folder_path) if f.lower().endswith(".mp4")]
    videos.sort()  # Ensure the files are renamed in order
    
    for index, video in enumerate(videos, start=1):
        new_name = f"Video {index:02d}.mp4"
        old_path = os.path.join(folder_path, video)
        new_path = os.path.join(folder_path, new_name)
        
        os.rename(old_path, new_path)
        print(f"Renamed: {video} -> {new_name}")

folder_path = "reduced_videos2"  
rename_videos(folder_path)
# Out:
# Renamed: Part1.mp4 -> Video 01.mp4
# Renamed: Part2-003.mp4 -> Video 02.mp4
# Renamed: Recording from 2025-03-03 09-11-03.688254.mp4 -> Video 03.mp4
# Renamed: Recording from 2025-03-03 10-51-23.391532.mp4 -> Video 04.mp4
# Renamed: WIN_20250303_09_11_30_Pro.mp4 -> Video 05.mp4
# Renamed: WIN_20250303_09_11_53_Pro.mp4 -> Video 06.mp4
# Renamed: WIN_20250303_09_16_32_Pro.mp4 -> Video 07.mp4
# Renamed: WIN_20250303_09_18_49_Pro.mp4 -> Video 08.mp4
# Renamed: WIN_20250303_09_19_13_Pro-002.mp4 -> Video 09.mp4
# Renamed: WIN_20250303_09_34_26_Pro(1)-011.mp4 -> Video 10.mp4
# Renamed: WIN_20250303_09_34_26_Pro-012.mp4 -> Video 11.mp4
# Renamed: WIN_20250303_10_47_26_Pro.mp4 -> Video 12.mp4
# Renamed: WIN_20250303_10_47_36_Pro.mp4 -> Video 13.mp4
# Renamed: WIN_20250303_10_47_46_Pro.mp4 -> Video 14.mp4
# Renamed: WIN_20250303_10_53_26_Pro(1)-009.mp4 -> Video 15.mp4
# Renamed: WIN_20250303_10_53_26_Pro-010.mp4 -> Video 16.mp4
# Renamed: WIN_20250303_10_53_46_Pro.mp4 -> Video 17.mp4
# Renamed: WIN_20250303_10_54_21_Pro-008.mp4 -> Video 18.mp4
# Renamed: WIN_20250303_10_55_18_Pro.mp4 -> Video 19.mp4
# Renamed: WIN_20250303_10_56_36_Pro-001.mp4 -> Video 20.mp4
# Renamed: WIN_20250303_10_56_37_Pro-006.mp4 -> Video 21.mp4
# Renamed: WIN_20250303_10_57_32_Pro.mp4 -> Video 22.mp4
# Renamed: WIN_20250303_10_59_21_Pro.mp4 -> Video 23.mp4
# Renamed: WIN_20250303_11_00_39_Pro.mp4 -> Video 24.mp4
# Renamed: WIN_20250303_11_11_38_Pro.mp4 -> Video 25.mp4
# Renamed: WIN_20250303_11_19_03_Pro.mp4 -> Video 26.mp4
# Renamed: WIN_20250303_11_39_36_Pro-005.mp4 -> Video 27.mp4

# %%
# Split videos into 15-second segments and save metadata in a CSV file

import os
import ffmpeg
import pandas as pd
from datetime import timedelta

def split_videos(input_folder, output_folder, segment_length=15):
    os.makedirs(output_folder, exist_ok=True)
    csv_data = []
    
    for file in os.listdir(input_folder):
        if file.endswith(".mp4"):
            video_path = os.path.join(input_folder, file)
            
            # Get video duration
            probe = ffmpeg.probe(video_path)
            duration = float(probe['format']['duration'])
            
            base_name = os.path.splitext(file)[0]
            segment_count = 1
            
            for start_time in range(0, int(duration), segment_length):
                end_time = min(start_time + segment_length, duration)
                split_name = f"{base_name}-{segment_count:03d}.mp4"
                output_path = os.path.join(output_folder, split_name)
                
                # Split the video
                ffmpeg.input(video_path, ss=start_time, t=segment_length).output(output_path, c="h264_nvenc").run(overwrite_output=True, quiet=True)
                
                # Save metadata for CSV
                csv_data.append([file, split_name, str(timedelta(seconds=start_time)), str(timedelta(seconds=end_time))])
                
                segment_count += 1
    
    # Save CSV
    csv_path = os.path.join(output_folder, "video_segments.csv")
    df = pd.DataFrame(csv_data, columns=["video_name", "split_video", "start_time", "end_time"])
    df.to_csv(csv_path, index=False)
    print(f"Processing complete! CSV saved at: {csv_path}")

split_videos("reduced_videos2", "D:\Recordings\Splitted_Videos")
# Out:
# Processing complete! CSV saved at: D:\Recordings\Splitted_Videos\video_segments.csv

# %%
# !pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu124
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu124
# Collecting torch
#   Downloading https://download.pytorch.org/whl/cu124/torch-2.4.1%2Bcu124-cp38-cp38-win_amd64.whl (2506.2 MB)
#      ---------------------------------------- 0.0/2.5 GB ? eta -:--:--
#      ---------------------------------------- 0.0/2.5 GB ? eta -:--:--
#      ---------------------------------------- 0.0/2.5 GB ? eta -:--:--
#      ---------------------------------------- 0.0/2.5 GB ? eta -:--:--
#      ---------------------------------------- 0.0/2.5 GB ? eta -:--:--
#      ---------------------------------------- 0.0/2.5 GB ? eta -:--:--
#      ---------------------------------------- 0.0/2.5 GB ? eta -:--:--
#      ---------------------------------------- 0.0/2.5 GB ? eta -:--:--
#      ---------------------------------------- 0.0/2.5 GB ? eta -:--:--
#      ---------------------------------------- 0.0/2.5 GB ? eta -:--:--
#      ---------------------------------------- 0.0/2.5 GB ? eta -:--:--
#      ---------------------------------------- 0.0/2.5 GB ? eta -:--:--
#      ---------------------------------------- 0.0/2.5 GB ? eta -:--:--
#      ---------------------------------------- 0.0/2.5 GB ? eta -:--:--
#      ---------------------------------------- 0.0/2.5 GB ? eta -:--:--
#      ---------------------------------------- 0.0/2.5 GB ? eta -:--:--
#      ---------------------------------------- 0.0/2.5 GB 39.7 kB/s eta 17:32:25
#      ---------------------------------------- 0.0/2.5 GB 39.7 kB/s eta 17:32:25
#      ---------------------------------------- 0.0/2.5 GB 39.7 kB/s eta 17:32:25
#      ---------------------------------------- 0.0/2.5 GB 39.7 kB/s eta 17:32:25
#      ---------------------------------------- 0.0/2.5 GB 39.7 kB/s eta 17:32:25
#      ---------------------------------------- 0.0/2.5 GB 39.7 kB/s eta 17:32:25
#      ---------------------------------------- 0.0/2.5 GB 39.7 kB/s eta 17:32:25
#      ---------------------------------------- 0.0/2.5 GB 48.5 kB/s eta 14:20:42
#      ---------------------------------------- 0.0/2.5 GB 48.5 kB/s eta 14:20:42
#      ---------------------------------------- 0.0/2.5 GB 48.5 kB/s eta 14:20:42
#      ---------------------------------------- 0.0/2.5 GB 48.5 kB/s eta 14:20:42
#      ---------------------------------------- 0.0/2.5 GB 48.5 kB/s eta 14:20:42
#      ---------------------------------------- 0.0/2.5 GB 46.1 kB/s eta 15:05:34
#      ---------------------------------------- 0.0/2.5 GB 46.1 kB/s eta 15:05:34
#      ---------------------------------------- 0.0/2.5 GB 46.1 kB/s eta 15:05:34
#      ---------------------------------------- 0.0/2.5 GB 46.1 kB/s eta 15:05:34
#      ---------------------------------------- 0.0/2.5 GB 46.1 kB/s eta 15:05:34
#      ---------------------------------------- 0.0/2.5 GB 46.1 kB/s eta 15:05:34
#      ---------------------------------------- 0.0/2.5 GB 46.1 kB/s eta 15:05:34
#      ---------------------------------------- 0.0/2.5 GB 46.1 kB/s eta 15:05:34
#      ---------------------------------------- 0.0/2.5 GB 46.1 kB/s eta 15:05:34
#      ---------------------------------------- 0.0/2.5 GB 46.1 kB/s eta 15:05:34
#      ---------------------------------------- 0.0/2.5 GB 46.3 kB/s eta 15:01:29
#      ---------------------------------------- 0.0/2.5 GB 46.3 kB/s eta 15:01:29
#      ---------------------------------------- 0.0/2.5 GB 46.3 kB/s eta 15:01:29
#      ---------------------------------------- 0.0/2.5 GB 46.3 kB/s eta 15:01:29
#      ---------------------------------------- 0.0/2.5 GB 46.3 kB/s eta 15:01:29
#      ---------------------------------------- 0.0/2.5 GB 51.3 kB/s eta 13:34:27
#      ---------------------------------------- 0.0/2.5 GB 51.3 kB/s eta 13:34:27
#      ---------------------------------------- 0.0/2.5 GB 51.3 kB/s eta 13:34:27
#      ---------------------------------------- 0.0/2.5 GB 51.3 kB/s eta 13:34:27
#      ---------------------------------------- 0.0/2.5 GB 51.3 kB/s eta 13:34:27
#      ---------------------------------------- 0.0/2.5 GB 51.3 kB/s eta 13:34:27
#      ---------------------------------------- 0.0/2.5 GB 51.3 kB/s eta 13:34:27
#      ---------------------------------------- 0.0/2.5 GB 48.2 kB/s eta 14:26:48
#      ---------------------------------------- 0.0/2.5 GB 48.2 kB/s eta 14:26:48
#      ---------------------------------------- 0.0/2.5 GB 48.2 kB/s eta 14:26:48
#      ---------------------------------------- 0.0/2.5 GB 48.2 kB/s eta 14:26:48
#      ---------------------------------------- 0.0/2.5 GB 48.2 kB/s eta 14:26:48
#      ---------------------------------------- 0.0/2.5 GB 51.4 kB/s eta 13:32:45
#      ---------------------------------------- 0.0/2.5 GB 51.4 kB/s eta 13:32:45
#      ---------------------------------------- 0.0/2.5 GB 51.4 kB/s eta 13:32:45
#      ---------------------------------------- 0.0/2.5 GB 51.4 kB/s eta 13:32:45
#      ---------------------------------------- 0.0/2.5 GB 55.9 kB/s eta 12:26:45
#      ---------------------------------------- 0.0/2.5 GB 55.9 kB/s eta 12:26:45
#      ---------------------------------------- 0.0/2.5 GB 58.2 kB/s eta 11:58:10
#      ---------------------------------------- 0.0/2.5 GB 58.2 kB/s eta 11:58:10
#      ---------------------------------------- 0.0/2.5 GB 58.2 kB/s eta 11:58:10
#      ---------------------------------------- 0.0/2.5 GB 58.2 kB/s eta 11:58:10
#      ---------------------------------------- 0.0/2.5 GB 58.2 kB/s eta 11:58:10
#      ---------------------------------------- 0.0/2.5 GB 60.2 kB/s eta 11:33:40
#      ---------------------------------------- 0.0/2.5 GB 60.2 kB/s eta 11:33:40
#      ---------------------------------------- 0.0/2.5 GB 60.2 kB/s eta 11:33:40
#      ---------------------------------------- 0.0/2.5 GB 60.2 kB/s eta 11:33:40
#      ---------------------------------------- 0.0/2.5 GB 60.2 kB/s eta 11:33:40
#      ---------------------------------------- 0.0/2.5 GB 60.2 kB/s eta 11:33:40
#      ---------------------------------------- 0.0/2.5 GB 68.1 kB/s eta 10:13:11
#      ---------------------------------------- 0.0/2.5 GB 68.1 kB/s eta 10:13:11
#      ---------------------------------------- 0.0/2.5 GB 68.1 kB/s eta 10:13:11
#      ---------------------------------------- 0.0/2.5 GB 68.1 kB/s eta 10:13:11
#      ---------------------------------------- 0.0/2.5 GB 68.1 kB/s eta 10:13:11
#      ---------------------------------------- 0.0/2.5 GB 72.1 kB/s eta 9:39:01
#      ---------------------------------------- 0.0/2.5 GB 72.1 kB/s eta 9:39:01
#      ---------------------------------------- 0.0/2.5 GB 72.1 kB/s eta 9:39:01
#      ---------------------------------------- 0.0/2.5 GB 72.1 kB/s eta 9:39:01
#      ---------------------------------------- 0.0/2.5 GB 72.1 kB/s eta 9:39:01
#      ---------------------------------------- 0.0/2.5 GB 72.1 kB/s eta 9:39:01
#      ---------------------------------------- 0.0/2.5 GB 75.3 kB/s eta 9:14:43
#      ---------------------------------------- 0.0/2.5 GB 75.3 kB/s eta 9:14:43
#      ---------------------------------------- 0.0/2.5 GB 75.3 kB/s eta 9:14:43
#      ---------------------------------------- 0.0/2.5 GB 77.3 kB/s eta 9:00:39
#      ---------------------------------------- 0.0/2.5 GB 83.5 kB/s eta 8:19:54
#      ---------------------------------------- 0.0/2.5 GB 83.5 kB/s eta 8:19:54
#      ---------------------------------------- 0.0/2.5 GB 83.5 kB/s eta 8:19:54
#      ---------------------------------------- 0.0/2.5 GB 83.5 kB/s eta 8:19:54
#      ---------------------------------------- 0.0/2.5 GB 84.7 kB/s eta 8:13:02
#      ---------------------------------------- 0.0/2.5 GB 93.3 kB/s eta 7:27:47
#      ---------------------------------------- 0.0/2.5 GB 93.3 kB/s eta 7:27:47
#      ---------------------------------------- 0.0/2.5 GB 93.3 kB/s eta 7:27:47
#      ---------------------------------------- 0.0/2.5 GB 91.6 kB/s eta 7:35:58
#      ---------------------------------------- 0.0/2.5 GB 91.6 kB/s eta 7:35:58
#      ---------------------------------------- 0.0/2.5 GB 101.5 kB/s eta 6:51:22
#      ---------------------------------------- 0.0/2.5 GB 101.5 kB/s eta 6:51:22
#      ---------------------------------------- 0.0/2.5 GB 101.5 kB/s eta 6:51:22
#      ---------------------------------------- 0.0/2.5 GB 101.5 kB/s eta 6:51:22
#      ---------------------------------------- 0.0/2.5 GB 101.8 kB/s eta 6:50:04
#      ---------------------------------------- 0.0/2.5 GB 101.8 kB/s eta 6:50:04
#      ---------------------------------------- 0.0/2.5 GB 115.8 kB/s eta 6:00:45
#      ---------------------------------------- 0.0/2.5 GB 115.8 kB/s eta 6:00:45
#      ---------------------------------------- 0.0/2.5 GB 115.8 kB/s eta 6:00:45
#      ---------------------------------------- 0.0/2.5 GB 115.8 kB/s eta 6:00:45
#      ---------------------------------------- 0.0/2.5 GB 115.8 kB/s eta 6:00:45
#      ---------------------------------------- 0.0/2.5 GB 126.1 kB/s eta 5:31:12
#      ---------------------------------------- 0.0/2.5 GB 126.1 kB/s eta 5:31:12
#      ---------------------------------------- 0.0/2.5 GB 126.1 kB/s eta 5:31:12
#      ---------------------------------------- 0.0/2.5 GB 126.1 kB/s eta 5:31:12
#      ---------------------------------------- 0.0/2.5 GB 126.1 kB/s eta 5:31:12
#      ---------------------------------------- 0.0/2.5 GB 125.1 kB/s eta 5:33:50
#      ---------------------------------------- 0.0/2.5 GB 141.7 kB/s eta 4:54:45
#      ---------------------------------------- 0.0/2.5 GB 141.7 kB/s eta 4:54:45
#      ---------------------------------------- 0.0/2.5 GB 141.7 kB/s eta 4:54:45
#      ---------------------------------------- 0.0/2.5 GB 141.7 kB/s eta 4:54:45
#      ---------------------------------------- 0.0/2.5 GB 141.7 kB/s eta 4:54:45
#      ---------------------------------------- 0.0/2.5 GB 153.5 kB/s eta 4:31:59
#      ---------------------------------------- 0.0/2.5 GB 153.5 kB/s eta 4:31:59
#      ---------------------------------------- 0.0/2.5 GB 153.5 kB/s eta 4:31:59
#      ---------------------------------------- 0.0/2.5 GB 153.5 kB/s eta 4:31:59
#      ---------------------------------------- 0.0/2.5 GB 150.7 kB/s eta 4:37:09
#      ---------------------------------------- 0.0/2.5 GB 150.7 kB/s eta 4:37:09
#      ---------------------------------------- 0.0/2.5 GB 170.1 kB/s eta 4:05:29
#      ---------------------------------------- 0.0/2.5 GB 170.1 kB/s eta 4:05:29
#      ---------------------------------------- 0.0/2.5 GB 170.1 kB/s eta 4:05:29
#      ---------------------------------------- 0.0/2.5 GB 167.3 kB/s eta 4:09:37
#      ---------------------------------------- 0.0/2.5 GB 186.5 kB/s eta 3:43:53
#      ---------------------------------------- 0.0/2.5 GB 186.5 kB/s eta 3:43:53
#      ---------------------------------------- 0.0/2.5 GB 186.5 kB/s eta 3:43:53
#      ---------------------------------------- 0.0/2.5 GB 186.5 kB/s eta 3:43:53
#      ---------------------------------------- 0.0/2.5 GB 184.6 kB/s eta 3:46:10
#      ---------------------------------------- 0.0/2.5 GB 203.7 kB/s eta 3:25:01
#      ---------------------------------------- 0.0/2.5 GB 203.7 kB/s eta 3:25:01
#      ---------------------------------------- 0.0/2.5 GB 203.7 kB/s eta 3:25:01
#      ---------------------------------------- 0.0/2.5 GB 203.7 kB/s eta 3:25:01
#      ---------------------------------------- 0.0/2.5 GB 201.4 kB/s eta 3:27:19
#      ---------------------------------------- 0.0/2.5 GB 201.4 kB/s eta 3:27:19
#      ---------------------------------------- 0.0/2.5 GB 222.6 kB/s eta 3:07:31
#      ---------------------------------------- 0.0/2.5 GB 222.6 kB/s eta 3:07:31
#      ---------------------------------------- 0.0/2.5 GB 222.6 kB/s eta 3:07:31
#      ---------------------------------------- 0.0/2.5 GB 222.6 kB/s eta 3:07:31
#      ---------------------------------------- 0.0/2.5 GB 221.5 kB/s eta 3:08:30
#      ---------------------------------------- 0.0/2.5 GB 245.8 kB/s eta 2:49:52
#      ---------------------------------------- 0.0/2.5 GB 245.8 kB/s eta 2:49:52
#      ---------------------------------------- 0.0/2.5 GB 245.8 kB/s eta 2:49:52
#      ---------------------------------------- 0.0/2.5 GB 245.8 kB/s eta 2:49:52
#      ---------------------------------------- 0.0/2.5 GB 241.1 kB/s eta 2:53:07
#      ---------------------------------------- 0.0/2.5 GB 241.1 kB/s eta 2:53:07
#      ---------------------------------------- 0.0/2.5 GB 266.2 kB/s eta 2:36:47
#      ---------------------------------------- 0.0/2.5 GB 266.2 kB/s eta 2:36:47
#      ---------------------------------------- 0.0/2.5 GB 266.2 kB/s eta 2:36:47
#      ---------------------------------------- 0.0/2.5 GB 266.2 kB/s eta 2:36:47
#      ---------------------------------------- 0.0/2.5 GB 263.6 kB/s eta 2:38:23
#      ---------------------------------------- 0.0/2.5 GB 293.1 kB/s eta 2:22:23
#      ---------------------------------------- 0.0/2.5 GB 293.1 kB/s eta 2:22:23
#      ---------------------------------------- 0.0/2.5 GB 293.1 kB/s eta 2:22:23
#      ---------------------------------------- 0.0/2.5 GB 293.1 kB/s eta 2:22:23
#      ---------------------------------------- 0.0/2.5 GB 287.7 kB/s eta 2:25:03
#      ---------------------------------------- 0.0/2.5 GB 287.7 kB/s eta 2:25:03
#      ---------------------------------------- 0.0/2.5 GB 317.4 kB/s eta 2:11:28
#      ---------------------------------------- 0.0/2.5 GB 317.4 kB/s eta 2:11:28
#      ---------------------------------------- 0.0/2.5 GB 317.4 kB/s eta 2:11:28
#      ---------------------------------------- 0.0/2.5 GB 317.4 kB/s eta 2:11:28
#      ---------------------------------------- 0.0/2.5 GB 313.7 kB/s eta 2:13:02
#      ---------------------------------------- 0.0/2.5 GB 313.7 kB/s eta 2:13:02
#      ---------------------------------------- 0.0/2.5 GB 347.4 kB/s eta 2:00:07
#      ---------------------------------------- 0.0/2.5 GB 347.4 kB/s eta 2:00:07
#      ---------------------------------------- 0.0/2.5 GB 347.4 kB/s eta 2:00:07
#      ---------------------------------------- 0.0/2.5 GB 341.2 kB/s eta 2:02:19
#      ---------------------------------------- 0.0/2.5 GB 342.4 kB/s eta 2:01:52
#      ---------------------------------------- 0.0/2.5 GB 374.8 kB/s eta 1:51:19
#      ---------------------------------------- 0.0/2.5 GB 374.8 kB/s eta 1:51:19
#      ---------------------------------------- 0.0/2.5 GB 374.8 kB/s eta 1:51:19
#      ---------------------------------------- 0.0/2.5 GB 374.8 kB/s eta 1:51:19
#      ---------------------------------------- 0.0/2.5 GB 370.6 kB/s eta 1:52:36
#      ---------------------------------------- 0.0/2.5 GB 407.3 kB/s eta 1:42:26
#      ---------------------------------------- 0.0/2.5 GB 407.3 kB/s eta 1:42:26
#      ---------------------------------------- 0.0/2.5 GB 407.3 kB/s eta 1:42:26
#      ---------------------------------------- 0.0/2.5 GB 407.3 kB/s eta 1:42:26
#      ---------------------------------------- 0.0/2.5 GB 400.7 kB/s eta 1:44:07
#      ---------------------------------------- 0.0/2.5 GB 401.2 kB/s eta 1:43:59
#      ---------------------------------------- 0.0/2.5 GB 411.8 kB/s eta 1:41:18
#      ---------------------------------------- 0.0/2.5 GB 438.1 kB/s eta 1:35:13
#      ---------------------------------------- 0.0/2.5 GB 438.1 kB/s eta 1:35:13
#      ---------------------------------------- 0.0/2.5 GB 438.1 kB/s eta 1:35:13
#      ---------------------------------------- 0.0/2.5 GB 438.1 kB/s eta 1:35:13
#      ---------------------------------------- 0.0/2.5 GB 474.1 kB/s eta 1:27:58
#      ---------------------------------------- 0.0/2.5 GB 474.1 kB/s eta 1:27:58
#      ---------------------------------------- 0.0/2.5 GB 474.1 kB/s eta 1:27:58
#      ---------------------------------------- 0.0/2.5 GB 474.1 kB/s eta 1:27:58
#      ---------------------------------------- 0.0/2.5 GB 468.8 kB/s eta 1:28:58
#      ---------------------------------------- 0.0/2.5 GB 493.8 kB/s eta 1:24:27
#      ---------------------------------------- 0.0/2.5 GB 509.8 kB/s eta 1:21:48
#      ---------------------------------------- 0.0/2.5 GB 509.8 kB/s eta 1:21:48
#      ---------------------------------------- 0.0/2.5 GB 509.8 kB/s eta 1:21:48
#      ---------------------------------------- 0.0/2.5 GB 505.0 kB/s eta 1:22:34
#      ---------------------------------------- 0.0/2.5 GB 549.8 kB/s eta 1:15:50
#      ---------------------------------------- 0.0/2.5 GB 549.8 kB/s eta 1:15:50
#      ---------------------------------------- 0.0/2.5 GB 549.8 kB/s eta 1:15:50
#      ---------------------------------------- 0.0/2.5 GB 549.8 kB/s eta 1:15:50
#      ---------------------------------------- 0.0/2.5 GB 543.4 kB/s eta 1:16:43
#      ---------------------------------------- 0.0/2.5 GB 589.0 kB/s eta 1:10:46
#      ---------------------------------------- 0.0/2.5 GB 589.3 kB/s eta 1:10:44
#      ---------------------------------------- 0.0/2.5 GB 589.3 kB/s eta 1:10:44
#      ---------------------------------------- 0.0/2.5 GB 589.3 kB/s eta 1:10:44
#      ---------------------------------------- 0.0/2.5 GB 584.1 kB/s eta 1:11:21
#      ---------------------------------------- 0.0/2.5 GB 632.4 kB/s eta 1:05:54
#      ---------------------------------------- 0.0/2.5 GB 632.4 kB/s eta 1:05:54
#      ---------------------------------------- 0.0/2.5 GB 632.4 kB/s eta 1:05:54
#      ---------------------------------------- 0.0/2.5 GB 625.7 kB/s eta 1:06:36
#      ---------------------------------------- 0.0/2.5 GB 660.4 kB/s eta 1:03:06
#      ---------------------------------------- 0.0/2.5 GB 677.7 kB/s eta 1:01:29
#      ---------------------------------------- 0.0/2.5 GB 674.5 kB/s eta 1:01:46
#      ---------------------------------------- 0.0/2.5 GB 674.5 kB/s eta 1:01:46
#      ---------------------------------------- 0.0/2.5 GB 671.3 kB/s eta 1:02:04
#      ---------------------------------------- 0.0/2.5 GB 672.3 kB/s eta 1:01:58
#      ---------------------------------------- 0.0/2.5 GB 726.6 kB/s eta 0:57:19
#      ---------------------------------------- 0.0/2.5 GB 726.6 kB/s eta 0:57:19
#      ---------------------------------------- 0.0/2.5 GB 726.6 kB/s eta 0:57:19
#      ---------------------------------------- 0.0/2.5 GB 726.6 kB/s eta 0:57:19
#      ---------------------------------------- 0.0/2.5 GB 720.4 kB/s eta 0:57:49
#      ---------------------------------------- 0.0/2.5 GB 776.0 kB/s eta 0:53:40
#      ---------------------------------------- 0.0/2.5 GB 776.0 kB/s eta 0:53:40
#      ---------------------------------------- 0.0/2.5 GB 776.0 kB/s eta 0:53:40
#      ---------------------------------------- 0.0/2.5 GB 776.0 kB/s eta 0:53:40
#      ---------------------------------------- 0.0/2.5 GB 769.3 kB/s eta 0:54:08
#      ---------------------------------------- 0.0/2.5 GB 770.1 kB/s eta 0:54:04
#      ---------------------------------------- 0.0/2.5 GB 828.8 kB/s eta 0:50:14
#      ---------------------------------------- 0.0/2.5 GB 828.8 kB/s eta 0:50:14
#      ---------------------------------------- 0.0/2.5 GB 828.8 kB/s eta 0:50:14
#      ---------------------------------------- 0.0/2.5 GB 828.8 kB/s eta 0:50:14
#      ---------------------------------------- 0.0/2.5 GB 821.0 kB/s eta 0:50:42
#      ---------------------------------------- 0.0/2.5 GB 882.7 kB/s eta 0:47:09
#      ---------------------------------------- 0.0/2.5 GB 882.7 kB/s eta 0:47:09
#      ---------------------------------------- 0.0/2.5 GB 882.7 kB/s eta 0:47:09
#      ---------------------------------------- 0.0/2.5 GB 882.7 kB/s eta 0:47:09
#      ---------------------------------------- 0.0/2.5 GB 875.6 kB/s eta 0:47:31
#      ---------------------------------------- 0.0/2.5 GB 875.9 kB/s eta 0:47:31
#      ---------------------------------------- 0.0/2.5 GB 1.5 MB/s eta 0:27:12
#      ---------------------------------------- 0.0/2.5 GB 1.5 MB/s eta 0:27:12
#      ---------------------------------------- 0.0/2.5 GB 1.5 MB/s eta 0:27:12
#      ---------------------------------------- 0.0/2.5 GB 1.5 MB/s eta 0:27:54
#      ---------------------------------------- 0.0/2.5 GB 1.5 MB/s eta 0:26:57
#      ---------------------------------------- 0.0/2.5 GB 2.0 MB/s eta 0:20:58
#      ---------------------------------------- 0.0/2.5 GB 2.0 MB/s eta 0:20:58
#      ---------------------------------------- 0.0/2.5 GB 2.0 MB/s eta 0:21:17
#      ---------------------------------------- 0.0/2.5 GB 2.0 MB/s eta 0:21:17
#      ---------------------------------------- 0.0/2.5 GB 2.0 MB/s eta 0:20:39
#      ---------------------------------------- 0.0/2.5 GB 2.0 MB/s eta 0:20:43
#      ---------------------------------------- 0.0/2.5 GB 2.4 MB/s eta 0:17:05
#      ---------------------------------------- 0.0/2.5 GB 2.4 MB/s eta 0:17:05
#      ---------------------------------------- 0.0/2.5 GB 2.4 MB/s eta 0:17:01
#      ---------------------------------------- 0.0/2.5 GB 2.4 MB/s eta 0:17:01
#      ---------------------------------------- 0.0/2.5 GB 2.4 MB/s eta 0:17:28
#      ---------------------------------------- 0.0/2.5 GB 2.7 MB/s eta 0:15:41
#      ---------------------------------------- 0.0/2.5 GB 2.9 MB/s eta 0:14:32
#      ---------------------------------------- 0.0/2.5 GB 2.8 MB/s eta 0:14:47
#      ---------------------------------------- 0.0/2.5 GB 2.8 MB/s eta 0:14:47
#      ---------------------------------------- 0.0/2.5 GB 2.7 MB/s eta 0:15:14
#      ---------------------------------------- 0.0/2.5 GB 2.7 MB/s eta 0:15:22
#      ---------------------------------------- 0.0/2.5 GB 3.1 MB/s eta 0:13:35
#      ---------------------------------------- 0.0/2.5 GB 3.1 MB/s eta 0:13:35
#      ---------------------------------------- 0.0/2.5 GB 3.0 MB/s eta 0:13:50
#      ---------------------------------------- 0.0/2.5 GB 3.1 MB/s eta 0:13:31
#      ---------------------------------------- 0.0/2.5 GB 3.1 MB/s eta 0:13:23
#      ---------------------------------------- 0.0/2.5 GB 3.3 MB/s eta 0:12:30
#      ---------------------------------------- 0.0/2.5 GB 3.6 MB/s eta 0:11:40
#      ---------------------------------------- 0.0/2.5 GB 3.6 MB/s eta 0:11:40
#      ---------------------------------------- 0.0/2.5 GB 3.6 MB/s eta 0:11:40
#      ---------------------------------------- 0.0/2.5 GB 3.4 MB/s eta 0:12:18
#      ---------------------------------------- 0.0/2.5 GB 4.0 MB/s eta 0:10:28
#      ---------------------------------------- 0.0/2.5 GB 4.0 MB/s eta 0:10:28
#      ---------------------------------------- 0.0/2.5 GB 4.0 MB/s eta 0:10:28
#      ---------------------------------------- 0.0/2.5 GB 3.7 MB/s eta 0:11:10
#      ---------------------------------------- 0.0/2.5 GB 3.7 MB/s eta 0:11:17
#      ---------------------------------------- 0.0/2.5 GB 4.4 MB/s eta 0:09:30
#      ---------------------------------------- 0.0/2.5 GB 4.3 MB/s eta 0:09:38
#      ---------------------------------------- 0.0/2.5 GB 4.3 MB/s eta 0:09:38
#      ---------------------------------------- 0.0/2.5 GB 4.3 MB/s eta 0:09:38
#      ---------------------------------------- 0.0/2.5 GB 4.1 MB/s eta 0:10:12
#      ---------------------------------------- 0.0/2.5 GB 4.4 MB/s eta 0:09:23
#      ---------------------------------------- 0.0/2.5 GB 4.8 MB/s eta 0:08:41
#      ---------------------------------------- 0.0/2.5 GB 4.8 MB/s eta 0:08:41
#      ---------------------------------------- 0.0/2.5 GB 4.8 MB/s eta 0:08:41
#      ---------------------------------------- 0.0/2.5 GB 4.5 MB/s eta 0:09:07
#      ---------------------------------------- 0.0/2.5 GB 4.5 MB/s eta 0:09:11
#      ---------------------------------------- 0.0/2.5 GB 5.0 MB/s eta 0:08:22
#      ---------------------------------------- 0.0/2.5 GB 4.9 MB/s eta 0:08:29
#      ---------------------------------------- 0.0/2.5 GB 4.8 MB/s eta 0:08:37
#      ---------------------------------------- 0.0/2.5 GB 4.8 MB/s eta 0:08:37
#      ---------------------------------------- 0.0/2.5 GB 4.5 MB/s eta 0:09:07
#      ---------------------------------------- 0.0/2.5 GB 5.0 MB/s eta 0:08:21
#      ---------------------------------------- 0.0/2.5 GB 5.5 MB/s eta 0:07:28
#      ---------------------------------------- 0.0/2.5 GB 5.5 MB/s eta 0:07:32
#      ---------------------------------------- 0.0/2.5 GB 5.5 MB/s eta 0:07:32
#      ---------------------------------------- 0.0/2.5 GB 5.2 MB/s eta 0:07:58
#      ---------------------------------------- 0.0/2.5 GB 5.1 MB/s eta 0:08:06
#      ---------------------------------------- 0.0/2.5 GB 5.6 MB/s eta 0:07:20
#      ---------------------------------------- 0.0/2.5 GB 5.6 MB/s eta 0:07:24
#      ---------------------------------------- 0.0/2.5 GB 5.4 MB/s eta 0:07:39
#      ---------------------------------------- 0.0/2.5 GB 5.4 MB/s eta 0:07:39
#      ---------------------------------------- 0.0/2.5 GB 5.6 MB/s eta 0:07:20
#      ---------------------------------------- 0.0/2.5 GB 5.7 MB/s eta 0:07:12
#      ---------------------------------------- 0.0/2.5 GB 6.5 MB/s eta 0:06:23
#      ---------------------------------------- 0.0/2.5 GB 6.3 MB/s eta 0:06:34
#      ---------------------------------------- 0.0/2.5 GB 6.3 MB/s eta 0:06:34
#      ---------------------------------------- 0.0/2.5 GB 5.9 MB/s eta 0:07:01
#      ---------------------------------------- 0.0/2.5 GB 5.8 MB/s eta 0:07:08
#      ---------------------------------------- 0.0/2.5 GB 6.6 MB/s eta 0:06:15
#      ---------------------------------------- 0.0/2.5 GB 6.4 MB/s eta 0:06:27
#      ---------------------------------------- 0.0/2.5 GB 6.1 MB/s eta 0:06:49
#      ---------------------------------------- 0.0/2.5 GB 6.0 MB/s eta 0:06:57
#      ---------------------------------------- 0.0/2.5 GB 7.7 MB/s eta 0:05:22
#      ---------------------------------------- 0.0/2.5 GB 7.5 MB/s eta 0:05:30
#      ---------------------------------------- 0.0/2.5 GB 7.5 MB/s eta 0:05:30
#      ---------------------------------------- 0.0/2.5 GB 7.0 MB/s eta 0:05:56
#      ---------------------------------------- 0.0/2.5 GB 6.8 MB/s eta 0:06:03
#       --------------------------------------- 0.0/2.5 GB 7.9 MB/s eta 0:05:14
#       --------------------------------------- 0.0/2.5 GB 7.7 MB/s eta 0:05:22
#       --------------------------------------- 0.0/2.5 GB 7.7 MB/s eta 0:05:22
#       --------------------------------------- 0.0/2.5 GB 7.7 MB/s eta 0:05:22
#       --------------------------------------- 0.0/2.5 GB 6.9 MB/s eta 0:05:59
#       --------------------------------------- 0.0/2.5 GB 7.7 MB/s eta 0:05:21
#       --------------------------------------- 0.0/2.5 GB 7.9 MB/s eta 0:05:14
#       --------------------------------------- 0.0/2.5 GB 7.6 MB/s eta 0:05:25
#       --------------------------------------- 0.0/2.5 GB 7.6 MB/s eta 0:05:25
#       --------------------------------------- 0.0/2.5 GB 7.1 MB/s eta 0:05:48
#       --------------------------------------- 0.0/2.5 GB 7.4 MB/s eta 0:05:37
#       --------------------------------------- 0.0/2.5 GB 7.9 MB/s eta 0:05:13
#       --------------------------------------- 0.0/2.5 GB 9.5 MB/s eta 0:04:21
#       --------------------------------------- 0.0/2.5 GB 9.2 MB/s eta 0:04:28
#       --------------------------------------- 0.0/2.5 GB 9.2 MB/s eta 0:04:28
#       --------------------------------------- 0.0/2.5 GB 8.3 MB/s eta 0:04:58
#       --------------------------------------- 0.0/2.5 GB 8.3 MB/s eta 0:04:58
#       --------------------------------------- 0.0/2.5 GB 7.8 MB/s eta 0:05:17
#       --------------------------------------- 0.0/2.5 GB 9.2 MB/s eta 0:04:28
#       --------------------------------------- 0.0/2.5 GB 9.2 MB/s eta 0:04:28
#       --------------------------------------- 0.0/2.5 GB 8.4 MB/s eta 0:04:54
#       --------------------------------------- 0.0/2.5 GB 8.3 MB/s eta 0:04:58
#       --------------------------------------- 0.0/2.5 GB 9.8 MB/s eta 0:04:13
#       --------------------------------------- 0.0/2.5 GB 9.6 MB/s eta 0:04:17
#       --------------------------------------- 0.0/2.5 GB 9.4 MB/s eta 0:04:24
#       --------------------------------------- 0.0/2.5 GB 9.4 MB/s eta 0:04:24
#       --------------------------------------- 0.0/2.5 GB 8.4 MB/s eta 0:04:54
#       --------------------------------------- 0.0/2.5 GB 9.8 MB/s eta 0:04:13
#       --------------------------------------- 0.0/2.5 GB 9.5 MB/s eta 0:04:20
#       --------------------------------------- 0.0/2.5 GB 9.4 MB/s eta 0:04:24
#       --------------------------------------- 0.0/2.5 GB 9.4 MB/s eta 0:04:24
#       --------------------------------------- 0.0/2.5 GB 9.8 MB/s eta 0:04:12
#       --------------------------------------- 0.0/2.5 GB 9.9 MB/s eta 0:04:08
#       --------------------------------------- 0.0/2.5 GB 11.9 MB/s eta 0:03:27
#       --------------------------------------- 0.0/2.5 GB 11.5 MB/s eta 0:03:35
#       --------------------------------------- 0.0/2.5 GB 11.5 MB/s eta 0:03:35
#       --------------------------------------- 0.0/2.5 GB 11.1 MB/s eta 0:03:42
#       --------------------------------------- 0.0/2.5 GB 10.4 MB/s eta 0:03:57
#       --------------------------------------- 0.1/2.5 GB 12.6 MB/s eta 0:03:15
#       --------------------------------------- 0.1/2.5 GB 12.1 MB/s eta 0:03:23
#       --------------------------------------- 0.1/2.5 GB 12.1 MB/s eta 0:03:23
#       --------------------------------------- 0.1/2.5 GB 12.1 MB/s eta 0:03:23
#       --------------------------------------- 0.1/2.5 GB 10.4 MB/s eta 0:03:57
#       --------------------------------------- 0.1/2.5 GB 11.9 MB/s eta 0:03:27
#       --------------------------------------- 0.1/2.5 GB 13.1 MB/s eta 0:03:08
#       --------------------------------------- 0.1/2.5 GB 13.1 MB/s eta 0:03:08
#       --------------------------------------- 0.1/2.5 GB 13.1 MB/s eta 0:03:08
#       --------------------------------------- 0.1/2.5 GB 13.1 MB/s eta 0:03:08
#       --------------------------------------- 0.1/2.5 GB 13.1 MB/s eta 0:03:08
#       --------------------------------------- 0.1/2.5 GB 12.8 MB/s eta 0:03:11
#       --------------------------------------- 0.1/2.5 GB 12.8 MB/s eta 0:03:11
#       --------------------------------------- 0.1/2.5 GB 12.8 MB/s eta 0:03:11
#       --------------------------------------- 0.1/2.5 GB 12.8 MB/s eta 0:03:11
#       --------------------------------------- 0.1/2.5 GB 12.8 MB/s eta 0:03:11
#       --------------------------------------- 0.1/2.5 GB 10.1 MB/s eta 0:04:03
#       --------------------------------------- 0.1/2.5 GB 12.4 MB/s eta 0:03:19
#       --------------------------------------- 0.1/2.5 GB 12.1 MB/s eta 0:03:22
#       --------------------------------------- 0.1/2.5 GB 12.1 MB/s eta 0:03:22
#       --------------------------------------- 0.1/2.5 GB 12.1 MB/s eta 0:03:22
#       --------------------------------------- 0.1/2.5 GB 12.1 MB/s eta 0:03:22
#       --------------------------------------- 0.1/2.5 GB 12.8 MB/s eta 0:03:11
#      - -------------------------------------- 0.1/2.5 GB 13.1 MB/s eta 0:03:07
#      - -------------------------------------- 0.1/2.5 GB 13.1 MB/s eta 0:03:07
#      - -------------------------------------- 0.1/2.5 GB 13.1 MB/s eta 0:03:07
#      - -------------------------------------- 0.1/2.5 GB 13.1 MB/s eta 0:03:07
#      - -------------------------------------- 0.1/2.5 GB 13.1 MB/s eta 0:03:07
#      - -------------------------------------- 0.1/2.5 GB 13.1 MB/s eta 0:03:07
#      - -------------------------------------- 0.1/2.5 GB 13.1 MB/s eta 0:03:07
#      - -------------------------------------- 0.1/2.5 GB 13.1 MB/s eta 0:03:07
#      - -------------------------------------- 0.1/2.5 GB 13.1 MB/s eta 0:03:07
#      - -------------------------------------- 0.1/2.5 GB 18.7 MB/s eta 0:02:11
#      - -------------------------------------- 0.1/2.5 GB 18.2 MB/s eta 0:02:15
#      - -------------------------------------- 0.1/2.5 GB 18.2 MB/s eta 0:02:15
#      - -------------------------------------- 0.1/2.5 GB 18.2 MB/s eta 0:02:15
#      - -------------------------------------- 0.1/2.5 GB 13.4 MB/s eta 0:03:03
#      - -------------------------------------- 0.1/2.5 GB 18.7 MB/s eta 0:02:11
#      - -------------------------------------- 0.1/2.5 GB 18.7 MB/s eta 0:02:11
#      - -------------------------------------- 0.1/2.5 GB 18.7 MB/s eta 0:02:11
#      - -------------------------------------- 0.1/2.5 GB 18.7 MB/s eta 0:02:11
#      - -------------------------------------- 0.1/2.5 GB 18.7 MB/s eta 0:02:10
#      - -------------------------------------- 0.1/2.5 GB 18.7 MB/s eta 0:02:10
#      - -------------------------------------- 0.1/2.5 GB 18.7 MB/s eta 0:02:10
#      - -------------------------------------- 0.1/2.5 GB 18.7 MB/s eta 0:02:10
#      - -------------------------------------- 0.1/2.5 GB 18.7 MB/s eta 0:02:10
#      - -------------------------------------- 0.1/2.5 GB 13.4 MB/s eta 0:03:02
#      - -------------------------------------- 0.1/2.5 GB 18.2 MB/s eta 0:02:14
#      - -------------------------------------- 0.1/2.5 GB 18.2 MB/s eta 0:02:14
#      - -------------------------------------- 0.1/2.5 GB 18.2 MB/s eta 0:02:14
#      - -------------------------------------- 0.1/2.5 GB 18.2 MB/s eta 0:02:14
#      - -------------------------------------- 0.1/2.5 GB 18.2 MB/s eta 0:02:14
#      - -------------------------------------- 0.1/2.5 GB 18.7 MB/s eta 0:02:10
#      - -------------------------------------- 0.1/2.5 GB 18.2 MB/s eta 0:02:14
#      - -------------------------------------- 0.1/2.5 GB 18.2 MB/s eta 0:02:14
#      - -------------------------------------- 0.1/2.5 GB 18.2 MB/s eta 0:02:14
#      - -------------------------------------- 0.1/2.5 GB 18.2 MB/s eta 0:02:14
#      - -------------------------------------- 0.1/2.5 GB 13.4 MB/s eta 0:03:01
#      - -------------------------------------- 0.1/2.5 GB 18.7 MB/s eta 0:02:10
#      - -------------------------------------- 0.1/2.5 GB 18.7 MB/s eta 0:02:10
#      - -------------------------------------- 0.1/2.5 GB 18.7 MB/s eta 0:02:10
#      - -------------------------------------- 0.1/2.5 GB 18.7 MB/s eta 0:02:10
#      - -------------------------------------- 0.1/2.5 GB 18.7 MB/s eta 0:02:10
#      - -------------------------------------- 0.1/2.5 GB 13.6 MB/s eta 0:02:57
#      - -------------------------------------- 0.1/2.5 GB 18.7 MB/s eta 0:02:09
#      - -------------------------------------- 0.1/2.5 GB 18.7 MB/s eta 0:02:09
#      - -------------------------------------- 0.1/2.5 GB 18.7 MB/s eta 0:02:09
#      - -------------------------------------- 0.1/2.5 GB 13.4 MB/s eta 0:03:01
#      - -------------------------------------- 0.1/2.5 GB 17.7 MB/s eta 0:02:17
#      - -------------------------------------- 0.1/2.5 GB 17.7 MB/s eta 0:02:17
#      - -------------------------------------- 0.1/2.5 GB 15.2 MB/s eta 0:02:39
#      - -------------------------------------- 0.1/2.5 GB 15.2 MB/s eta 0:02:39
#      - -------------------------------------- 0.1/2.5 GB 15.2 MB/s eta 0:02:39
#      - -------------------------------------- 0.1/2.5 GB 13.1 MB/s eta 0:03:04
#      - -------------------------------------- 0.1/2.5 GB 12.4 MB/s eta 0:03:15
#      - -------------------------------------- 0.1/2.5 GB 16.4 MB/s eta 0:02:27
#      - -------------------------------------- 0.1/2.5 GB 16.4 MB/s eta 0:02:27
#      - -------------------------------------- 0.1/2.5 GB 16.4 MB/s eta 0:02:27
#      - -------------------------------------- 0.1/2.5 GB 13.4 MB/s eta 0:03:00
#      - -------------------------------------- 0.1/2.5 GB 18.2 MB/s eta 0:02:13
#      - -------------------------------------- 0.1/2.5 GB 18.2 MB/s eta 0:02:13
#      - -------------------------------------- 0.1/2.5 GB 18.2 MB/s eta 0:02:13
#      - -------------------------------------- 0.1/2.5 GB 18.2 MB/s eta 0:02:13
#      - -------------------------------------- 0.1/2.5 GB 13.6 MB/s eta 0:02:56
#      - -------------------------------------- 0.1/2.5 GB 21.8 MB/s eta 0:01:50
#      - -------------------------------------- 0.1/2.5 GB 21.8 MB/s eta 0:01:50
#      - -------------------------------------- 0.1/2.5 GB 21.8 MB/s eta 0:01:50
#      - -------------------------------------- 0.1/2.5 GB 21.8 MB/s eta 0:01:50
#      - -------------------------------------- 0.1/2.5 GB 21.8 MB/s eta 0:01:50
#      - -------------------------------------- 0.1/2.5 GB 14.6 MB/s eta 0:02:45
#      - -------------------------------------- 0.1/2.5 GB 18.7 MB/s eta 0:02:08
#      - -------------------------------------- 0.1/2.5 GB 18.7 MB/s eta 0:02:08
#      - -------------------------------------- 0.1/2.5 GB 18.7 MB/s eta 0:02:08
#      - -------------------------------------- 0.1/2.5 GB 18.7 MB/s eta 0:02:08
#      - -------------------------------------- 0.1/2.5 GB 18.7 MB/s eta 0:02:08
#      - -------------------------------------- 0.1/2.5 GB 18.7 MB/s eta 0:02:08
#      - -------------------------------------- 0.1/2.5 GB 17.7 MB/s eta 0:02:15
#      - -------------------------------------- 0.1/2.5 GB 17.7 MB/s eta 0:02:15
#      - -------------------------------------- 0.1/2.5 GB 17.7 MB/s eta 0:02:15
#      - -------------------------------------- 0.1/2.5 GB 18.7 MB/s eta 0:02:08
#      - -------------------------------------- 0.1/2.5 GB 18.2 MB/s eta 0:02:11
#      - -------------------------------------- 0.1/2.5 GB 18.2 MB/s eta 0:02:11
#      - -------------------------------------- 0.1/2.5 GB 18.2 MB/s eta 0:02:11
#      - -------------------------------------- 0.1/2.5 GB 18.2 MB/s eta 0:02:11
#      - -------------------------------------- 0.1/2.5 GB 13.6 MB/s eta 0:02:55
#      -- ------------------------------------- 0.1/2.5 GB 18.7 MB/s eta 0:02:08
#      -- ------------------------------------- 0.1/2.5 GB 18.7 MB/s eta 0:02:08
#      -- ------------------------------------- 0.1/2.5 GB 18.7 MB/s eta 0:02:08
#      -- ------------------------------------- 0.1/2.5 GB 13.6 MB/s eta 0:02:55
#      -- ------------------------------------- 0.1/2.5 GB 18.7 MB/s eta 0:02:08
#      -- ------------------------------------- 0.1/2.5 GB 18.7 MB/s eta 0:02:08
#      -- ------------------------------------- 0.1/2.5 GB 18.7 MB/s eta 0:02:08
#      -- ------------------------------------- 0.1/2.5 GB 18.7 MB/s eta 0:02:08
#      -- ------------------------------------- 0.1/2.5 GB 13.9 MB/s eta 0:02:51
#      -- ------------------------------------- 0.1/2.5 GB 18.2 MB/s eta 0:02:11
#      -- ------------------------------------- 0.1/2.5 GB 18.2 MB/s eta 0:02:11
#      -- ------------------------------------- 0.1/2.5 GB 18.2 MB/s eta 0:02:11
#      -- ------------------------------------- 0.1/2.5 GB 18.2 MB/s eta 0:02:11
#      -- ------------------------------------- 0.1/2.5 GB 18.2 MB/s eta 0:02:11
#      -- ------------------------------------- 0.1/2.5 GB 18.7 MB/s eta 0:02:07
#      -- ------------------------------------- 0.1/2.5 GB 18.2 MB/s eta 0:02:11
#      -- ------------------------------------- 0.1/2.5 GB 18.2 MB/s eta 0:02:11
#      -- ------------------------------------- 0.1/2.5 GB 18.2 MB/s eta 0:02:11
#      -- ------------------------------------- 0.1/2.5 GB 18.2 MB/s eta 0:02:11
#      -- ------------------------------------- 0.1/2.5 GB 13.4 MB/s eta 0:02:58
#      -- ------------------------------------- 0.1/2.5 GB 17.2 MB/s eta 0:02:18
#      -- ------------------------------------- 0.1/2.5 GB 16.8 MB/s eta 0:02:21
#      -- ------------------------------------- 0.1/2.5 GB 16.8 MB/s eta 0:02:21
#      -- ------------------------------------- 0.1/2.5 GB 16.8 MB/s eta 0:02:21
#      -- ------------------------------------- 0.1/2.5 GB 13.6 MB/s eta 0:02:54
#      -- ------------------------------------- 0.1/2.5 GB 18.7 MB/s eta 0:02:07
#      -- ------------------------------------- 0.1/2.5 GB 18.7 MB/s eta 0:02:07
#      -- ------------------------------------- 0.1/2.5 GB 18.7 MB/s eta 0:02:07
#      -- ------------------------------------- 0.1/2.5 GB 18.7 MB/s eta 0:02:07
#      -- ------------------------------------- 0.1/2.5 GB 13.6 MB/s eta 0:02:54
#      -- ------------------------------------- 0.1/2.5 GB 13.4 MB/s eta 0:02:57
#      -- ------------------------------------- 0.1/2.5 GB 13.4 MB/s eta 0:02:57
#      -- ------------------------------------- 0.1/2.5 GB 13.4 MB/s eta 0:02:57
#      -- ------------------------------------- 0.1/2.5 GB 13.4 MB/s eta 0:02:57
#      -- ------------------------------------- 0.1/2.5 GB 13.4 MB/s eta 0:02:57
#      -- ------------------------------------- 0.1/2.5 GB 13.9 MB/s eta 0:02:50
#      -- ------------------------------------- 0.2/2.5 GB 13.9 MB/s eta 0:02:49
#      -- ------------------------------------- 0.2/2.5 GB 13.9 MB/s eta 0:02:49
#      -- ------------------------------------- 0.2/2.5 GB 13.9 MB/s eta 0:02:49
#      -- ------------------------------------- 0.2/2.5 GB 13.9 MB/s eta 0:02:49
#      -- ------------------------------------- 0.2/2.5 GB 10.9 MB/s eta 0:03:36
#      -- ------------------------------------- 0.2/2.5 GB 13.1 MB/s eta 0:03:00
#      -- ------------------------------------- 0.2/2.5 GB 13.1 MB/s eta 0:03:00
#      -- ------------------------------------- 0.2/2.5 GB 13.1 MB/s eta 0:03:00
#      -- ------------------------------------- 0.2/2.5 GB 13.1 MB/s eta 0:03:00
#      -- ------------------------------------- 0.2/2.5 GB 13.1 MB/s eta 0:03:00
#      -- ------------------------------------- 0.2/2.5 GB 13.4 MB/s eta 0:02:56
#      -- ------------------------------------- 0.2/2.5 GB 18.7 MB/s eta 0:02:06
#      -- ------------------------------------- 0.2/2.5 GB 18.7 MB/s eta 0:02:06
#      -- ------------------------------------- 0.2/2.5 GB 18.7 MB/s eta 0:02:06
#      -- ------------------------------------- 0.2/2.5 GB 13.9 MB/s eta 0:02:49
#      -- ------------------------------------- 0.2/2.5 GB 13.6 MB/s eta 0:02:52
#      -- ------------------------------------- 0.2/2.5 GB 18.2 MB/s eta 0:02:09
#      -- ------------------------------------- 0.2/2.5 GB 18.2 MB/s eta 0:02:09
#      -- ------------------------------------- 0.2/2.5 GB 18.2 MB/s eta 0:02:09
#      -- ------------------------------------- 0.2/2.5 GB 18.2 MB/s eta 0:02:09
#      -- ------------------------------------- 0.2/2.5 GB 13.4 MB/s eta 0:02:56
#      -- ------------------------------------- 0.2/2.5 GB 18.2 MB/s eta 0:02:09
#      -- ------------------------------------- 0.2/2.5 GB 18.2 MB/s eta 0:02:09
#      -- ------------------------------------- 0.2/2.5 GB 18.2 MB/s eta 0:02:09
#      -- ------------------------------------- 0.2/2.5 GB 18.2 MB/s eta 0:02:09
#      -- ------------------------------------- 0.2/2.5 GB 18.2 MB/s eta 0:02:09
#      -- ------------------------------------- 0.2/2.5 GB 13.6 MB/s eta 0:02:52
#      -- ------------------------------------- 0.2/2.5 GB 17.7 MB/s eta 0:02:12
#      -- ------------------------------------- 0.2/2.5 GB 17.7 MB/s eta 0:02:12
#      -- ------------------------------------- 0.2/2.5 GB 17.7 MB/s eta 0:02:12
#      -- ------------------------------------- 0.2/2.5 GB 17.7 MB/s eta 0:02:12
#      -- ------------------------------------- 0.2/2.5 GB 13.4 MB/s eta 0:02:55
#      -- ------------------------------------- 0.2/2.5 GB 13.4 MB/s eta 0:02:55
#      -- ------------------------------------- 0.2/2.5 GB 13.4 MB/s eta 0:02:55
#      -- ------------------------------------- 0.2/2.5 GB 13.4 MB/s eta 0:02:55
#      -- ------------------------------------- 0.2/2.5 GB 13.4 MB/s eta 0:02:55
#      -- ------------------------------------- 0.2/2.5 GB 13.4 MB/s eta 0:02:55
#      -- ------------------------------------- 0.2/2.5 GB 13.6 MB/s eta 0:02:51
#      -- ------------------------------------- 0.2/2.5 GB 13.4 MB/s eta 0:02:55
#      -- ------------------------------------- 0.2/2.5 GB 13.4 MB/s eta 0:02:55
#      -- ------------------------------------- 0.2/2.5 GB 13.4 MB/s eta 0:02:55
#      -- ------------------------------------- 0.2/2.5 GB 13.9 MB/s eta 0:02:48
#      -- ------------------------------------- 0.2/2.5 GB 17.7 MB/s eta 0:02:12
#      -- ------------------------------------- 0.2/2.5 GB 17.7 MB/s eta 0:02:12
#      -- ------------------------------------- 0.2/2.5 GB 17.7 MB/s eta 0:02:12
#      -- ------------------------------------- 0.2/2.5 GB 17.7 MB/s eta 0:02:12
#      -- ------------------------------------- 0.2/2.5 GB 17.7 MB/s eta 0:02:12
#      -- ------------------------------------- 0.2/2.5 GB 18.2 MB/s eta 0:02:08
#      -- ------------------------------------- 0.2/2.5 GB 18.2 MB/s eta 0:02:08
#      -- ------------------------------------- 0.2/2.5 GB 18.2 MB/s eta 0:02:08
#      -- ------------------------------------- 0.2/2.5 GB 16.0 MB/s eta 0:02:26
#      -- ------------------------------------- 0.2/2.5 GB 16.0 MB/s eta 0:02:26
#      -- ------------------------------------- 0.2/2.5 GB 13.4 MB/s eta 0:02:54
#      --- ------------------------------------ 0.2/2.5 GB 18.2 MB/s eta 0:02:08
#      --- ------------------------------------ 0.2/2.5 GB 18.2 MB/s eta 0:02:08
#      --- ------------------------------------ 0.2/2.5 GB 18.2 MB/s eta 0:02:08
#      --- ------------------------------------ 0.2/2.5 GB 18.2 MB/s eta 0:02:08
#      --- ------------------------------------ 0.2/2.5 GB 18.2 MB/s eta 0:02:08
#      --- ------------------------------------ 0.2/2.5 GB 18.2 MB/s eta 0:02:08
#      --- ------------------------------------ 0.2/2.5 GB 18.7 MB/s eta 0:02:04
#      --- ------------------------------------ 0.2/2.5 GB 18.7 MB/s eta 0:02:04
#      --- ------------------------------------ 0.2/2.5 GB 18.7 MB/s eta 0:02:04
#      --- ------------------------------------ 0.2/2.5 GB 18.7 MB/s eta 0:02:04
#      --- ------------------------------------ 0.2/2.5 GB 13.4 MB/s eta 0:02:54
#      --- ------------------------------------ 0.2/2.5 GB 18.2 MB/s eta 0:02:08
#      --- ------------------------------------ 0.2/2.5 GB 18.7 MB/s eta 0:02:04
#      --- ------------------------------------ 0.2/2.5 GB 18.7 MB/s eta 0:02:04
#      --- ------------------------------------ 0.2/2.5 GB 18.7 MB/s eta 0:02:04
#      --- ------------------------------------ 0.2/2.5 GB 18.7 MB/s eta 0:02:04
#      --- ------------------------------------ 0.2/2.5 GB 13.6 MB/s eta 0:02:50
#      --- ------------------------------------ 0.2/2.5 GB 18.2 MB/s eta 0:02:07
#      --- ------------------------------------ 0.2/2.5 GB 18.2 MB/s eta 0:02:07
#      --- ------------------------------------ 0.2/2.5 GB 18.2 MB/s eta 0:02:07
#      --- ------------------------------------ 0.2/2.5 GB 18.2 MB/s eta 0:02:07
#      --- ------------------------------------ 0.2/2.5 GB 13.4 MB/s eta 0:02:53
#      --- ------------------------------------ 0.2/2.5 GB 18.7 MB/s eta 0:02:04
#      --- ------------------------------------ 0.2/2.5 GB 18.7 MB/s eta 0:02:04
#      --- ------------------------------------ 0.2/2.5 GB 18.7 MB/s eta 0:02:04
#      --- ------------------------------------ 0.2/2.5 GB 18.7 MB/s eta 0:02:04
#      --- ------------------------------------ 0.2/2.5 GB 18.7 MB/s eta 0:02:04
#      --- ------------------------------------ 0.2/2.5 GB 18.2 MB/s eta 0:02:07
#      --- ------------------------------------ 0.2/2.5 GB 18.2 MB/s eta 0:02:07
#      --- ------------------------------------ 0.2/2.5 GB 18.2 MB/s eta 0:02:07
#      --- ------------------------------------ 0.2/2.5 GB 18.2 MB/s eta 0:02:07
#      --- ------------------------------------ 0.2/2.5 GB 13.6 MB/s eta 0:02:49
#      --- ------------------------------------ 0.2/2.5 GB 18.2 MB/s eta 0:02:07
#      --- ------------------------------------ 0.2/2.5 GB 18.2 MB/s eta 0:02:07
#      --- ------------------------------------ 0.2/2.5 GB 18.2 MB/s eta 0:02:07
#      --- ------------------------------------ 0.2/2.5 GB 18.2 MB/s eta 0:02:07
#      --- ------------------------------------ 0.2/2.5 GB 13.6 MB/s eta 0:02:49
#      --- ------------------------------------ 0.2/2.5 GB 18.7 MB/s eta 0:02:03
#      --- ------------------------------------ 0.2/2.5 GB 18.7 MB/s eta 0:02:03
#      --- ------------------------------------ 0.2/2.5 GB 18.7 MB/s eta 0:02:03
#      --- ------------------------------------ 0.2/2.5 GB 18.7 MB/s eta 0:02:03
#      --- ------------------------------------ 0.2/2.5 GB 18.7 MB/s eta 0:02:03
#      --- ------------------------------------ 0.2/2.5 GB 13.6 MB/s eta 0:02:48
#      --- ------------------------------------ 0.2/2.5 GB 18.2 MB/s eta 0:02:06
#      --- ------------------------------------ 0.2/2.5 GB 18.2 MB/s eta 0:02:06
#      --- ------------------------------------ 0.2/2.5 GB 18.2 MB/s eta 0:02:06
#      --- ------------------------------------ 0.2/2.5 GB 18.2 MB/s eta 0:02:06
#      --- ------------------------------------ 0.2/2.5 GB 13.6 MB/s eta 0:02:48
#      --- ------------------------------------ 0.2/2.5 GB 18.2 MB/s eta 0:02:06
#      --- ------------------------------------ 0.2/2.5 GB 18.7 MB/s eta 0:02:03
#      --- ------------------------------------ 0.2/2.5 GB 18.7 MB/s eta 0:02:03
#      --- ------------------------------------ 0.2/2.5 GB 18.7 MB/s eta 0:02:03
#      --- ------------------------------------ 0.2/2.5 GB 18.7 MB/s eta 0:02:03
# ...
#      ---------------------------------------- 0.0/4.1 MB ? eta -:--:--
#      ---------------------------------------- 0.0/4.1 MB ? eta -:--:--
#      ---------------------------------------- 0.0/4.1 MB ? eta -:--:--
#      ---------------------------------------- 0.0/4.1 MB ? eta -:--:--
#      ---------------------------------------- 0.0/4.1 MB ? eta -:--:--
#      ---------------------------------------- 0.0/4.1 MB ? eta -:--:--
#      ---------------------------------------- 0.0/4.1 MB 38.5 kB/s eta 0:01:47
#      ---------------------------------------- 0.0/4.1 MB 38.5 kB/s eta 0:01:47
#      ---------------------------------------- 0.0/4.1 MB 38.5 kB/s eta 0:01:47
#      ---------------------------------------- 0.0/4.1 MB 38.5 kB/s eta 0:01:47
#      ---------------------------------------- 0.0/4.1 MB 38.5 kB/s eta 0:01:47
#      ---------------------------------------- 0.0/4.1 MB 38.5 kB/s eta 0:01:47
#      ---------------------------------------- 0.0/4.1 MB 39.3 kB/s eta 0:01:44
#      ---------------------------------------- 0.1/4.1 MB 47.6 kB/s eta 0:01:26
#      ---------------------------------------- 0.1/4.1 MB 47.6 kB/s eta 0:01:26
#      ---------------------------------------- 0.1/4.1 MB 47.6 kB/s eta 0:01:26
#      ---------------------------------------- 0.1/4.1 MB 47.6 kB/s eta 0:01:26
#      ---------------------------------------- 0.1/4.1 MB 47.6 kB/s eta 0:01:26
#       --------------------------------------- 0.1/4.1 MB 46.1 kB/s eta 0:01:29
#       --------------------------------------- 0.1/4.1 MB 46.1 kB/s eta 0:01:29
#       --------------------------------------- 0.1/4.1 MB 46.1 kB/s eta 0:01:29
#       --------------------------------------- 0.1/4.1 MB 46.1 kB/s eta 0:01:29
#       --------------------------------------- 0.1/4.1 MB 46.1 kB/s eta 0:01:29
#       --------------------------------------- 0.1/4.1 MB 46.1 kB/s eta 0:01:29
#       --------------------------------------- 0.1/4.1 MB 46.1 kB/s eta 0:01:29
#       --------------------------------------- 0.1/4.1 MB 46.1 kB/s eta 0:01:29
#       --------------------------------------- 0.1/4.1 MB 46.1 kB/s eta 0:01:29
#       --------------------------------------- 0.1/4.1 MB 45.9 kB/s eta 0:01:29
#       --------------------------------------- 0.1/4.1 MB 45.9 kB/s eta 0:01:29
#       --------------------------------------- 0.1/4.1 MB 45.9 kB/s eta 0:01:29
#       --------------------------------------- 0.1/4.1 MB 45.9 kB/s eta 0:01:29
#       --------------------------------------- 0.1/4.1 MB 45.9 kB/s eta 0:01:29
#       --------------------------------------- 0.1/4.1 MB 45.9 kB/s eta 0:01:29
#       --------------------------------------- 0.1/4.1 MB 50.8 kB/s eta 0:01:20
#       --------------------------------------- 0.1/4.1 MB 50.8 kB/s eta 0:01:20
#       --------------------------------------- 0.1/4.1 MB 50.8 kB/s eta 0:01:20
#       --------------------------------------- 0.1/4.1 MB 50.8 kB/s eta 0:01:20
#       --------------------------------------- 0.1/4.1 MB 50.8 kB/s eta 0:01:20
#       --------------------------------------- 0.1/4.1 MB 50.8 kB/s eta 0:01:20
#       --------------------------------------- 0.1/4.1 MB 50.8 kB/s eta 0:01:20
#      - -------------------------------------- 0.1/4.1 MB 47.8 kB/s eta 0:01:24
#      - -------------------------------------- 0.1/4.1 MB 47.8 kB/s eta 0:01:24
#      - -------------------------------------- 0.1/4.1 MB 47.8 kB/s eta 0:01:24
#      - -------------------------------------- 0.1/4.1 MB 47.8 kB/s eta 0:01:24
#      - -------------------------------------- 0.1/4.1 MB 47.8 kB/s eta 0:01:24
#      - -------------------------------------- 0.1/4.1 MB 51.1 kB/s eta 0:01:19
#      - -------------------------------------- 0.1/4.1 MB 51.1 kB/s eta 0:01:19
#      - -------------------------------------- 0.1/4.1 MB 51.1 kB/s eta 0:01:19
#      - -------------------------------------- 0.1/4.1 MB 51.1 kB/s eta 0:01:19
#      - -------------------------------------- 0.2/4.1 MB 55.3 kB/s eta 0:01:12
#      - -------------------------------------- 0.2/4.1 MB 55.3 kB/s eta 0:01:12
#      - -------------------------------------- 0.2/4.1 MB 57.8 kB/s eta 0:01:09
#      - -------------------------------------- 0.2/4.1 MB 57.8 kB/s eta 0:01:09
#      - -------------------------------------- 0.2/4.1 MB 57.8 kB/s eta 0:01:09
#      - -------------------------------------- 0.2/4.1 MB 57.8 kB/s eta 0:01:09
#      - -------------------------------------- 0.2/4.1 MB 57.8 kB/s eta 0:01:09
#      - -------------------------------------- 0.2/4.1 MB 59.6 kB/s eta 0:01:07
#      - -------------------------------------- 0.2/4.1 MB 59.6 kB/s eta 0:01:07
#      - -------------------------------------- 0.2/4.1 MB 59.6 kB/s eta 0:01:07
#      - -------------------------------------- 0.2/4.1 MB 59.6 kB/s eta 0:01:07
#      - -------------------------------------- 0.2/4.1 MB 59.6 kB/s eta 0:01:07
#      - -------------------------------------- 0.2/4.1 MB 59.6 kB/s eta 0:01:07
#      -- ------------------------------------- 0.2/4.1 MB 67.5 kB/s eta 0:00:58
#      -- ------------------------------------- 0.2/4.1 MB 67.5 kB/s eta 0:00:58
#      -- ------------------------------------- 0.2/4.1 MB 67.5 kB/s eta 0:00:58
#      -- ------------------------------------- 0.2/4.1 MB 67.5 kB/s eta 0:00:58
#      -- ------------------------------------- 0.2/4.1 MB 67.5 kB/s eta 0:00:58
#      -- ------------------------------------- 0.3/4.1 MB 71.5 kB/s eta 0:00:55
#      -- ------------------------------------- 0.3/4.1 MB 71.5 kB/s eta 0:00:55
#      -- ------------------------------------- 0.3/4.1 MB 71.5 kB/s eta 0:00:55
#      -- ------------------------------------- 0.3/4.1 MB 71.5 kB/s eta 0:00:55
#      -- ------------------------------------- 0.3/4.1 MB 73.4 kB/s eta 0:00:53
#      -- ------------------------------------- 0.3/4.1 MB 73.4 kB/s eta 0:00:53
#      -- ------------------------------------- 0.3/4.1 MB 74.7 kB/s eta 0:00:52
#      -- ------------------------------------- 0.3/4.1 MB 74.7 kB/s eta 0:00:52
#      -- ------------------------------------- 0.3/4.1 MB 74.7 kB/s eta 0:00:52
#      -- ------------------------------------- 0.3/4.1 MB 74.7 kB/s eta 0:00:52
#      -- ------------------------------------- 0.3/4.1 MB 76.3 kB/s eta 0:00:50
#      --- ------------------------------------ 0.3/4.1 MB 82.9 kB/s eta 0:00:46
#      --- ------------------------------------ 0.3/4.1 MB 82.9 kB/s eta 0:00:46
#      --- ------------------------------------ 0.3/4.1 MB 82.9 kB/s eta 0:00:46
#      --- ------------------------------------ 0.3/4.1 MB 82.9 kB/s eta 0:00:46
#      --- ------------------------------------ 0.4/4.1 MB 84.1 kB/s eta 0:00:45
#      --- ------------------------------------ 0.4/4.1 MB 94.7 kB/s eta 0:00:40
#      --- ------------------------------------ 0.4/4.1 MB 94.7 kB/s eta 0:00:40
#      --- ------------------------------------ 0.4/4.1 MB 94.7 kB/s eta 0:00:40
#      --- ------------------------------------ 0.4/4.1 MB 94.7 kB/s eta 0:00:40
#      --- ------------------------------------ 0.4/4.1 MB 94.7 kB/s eta 0:00:40
#      ---- ----------------------------------- 0.4/4.1 MB 91.7 kB/s eta 0:00:41
#      ---- ----------------------------------- 0.5/4.1 MB 100.8 kB/s eta 0:00:37
#      ---- ----------------------------------- 0.5/4.1 MB 100.8 kB/s eta 0:00:37
#      ---- ----------------------------------- 0.5/4.1 MB 100.8 kB/s eta 0:00:37
#      ---- ----------------------------------- 0.5/4.1 MB 100.8 kB/s eta 0:00:37
#      ---- ----------------------------------- 0.5/4.1 MB 100.8 kB/s eta 0:00:37
#      ----- ---------------------------------- 0.6/4.1 MB 114.6 kB/s eta 0:00:32
#      ----- ---------------------------------- 0.6/4.1 MB 114.6 kB/s eta 0:00:32
#      ----- ---------------------------------- 0.6/4.1 MB 114.6 kB/s eta 0:00:32
#      ----- ---------------------------------- 0.6/4.1 MB 114.6 kB/s eta 0:00:32
#      ----- ---------------------------------- 0.6/4.1 MB 114.4 kB/s eta 0:00:32
#      ----- ---------------------------------- 0.6/4.1 MB 114.4 kB/s eta 0:00:32
#      ------ --------------------------------- 0.6/4.1 MB 125.3 kB/s eta 0:00:28
#      ------ --------------------------------- 0.6/4.1 MB 125.3 kB/s eta 0:00:28
#      ------ --------------------------------- 0.6/4.1 MB 125.3 kB/s eta 0:00:28
#      ------ --------------------------------- 0.6/4.1 MB 125.3 kB/s eta 0:00:28
#      ------ --------------------------------- 0.7/4.1 MB 124.3 kB/s eta 0:00:28
#      ------- -------------------------------- 0.7/4.1 MB 140.4 kB/s eta 0:00:25
#      ------- -------------------------------- 0.7/4.1 MB 140.4 kB/s eta 0:00:25
#      ------- -------------------------------- 0.7/4.1 MB 140.4 kB/s eta 0:00:25
#      ------- -------------------------------- 0.7/4.1 MB 140.4 kB/s eta 0:00:25
#      ------- -------------------------------- 0.8/4.1 MB 137.5 kB/s eta 0:00:25
#      ------- -------------------------------- 0.8/4.1 MB 137.5 kB/s eta 0:00:25
#      -------- ------------------------------- 0.9/4.1 MB 154.1 kB/s eta 0:00:22
#      -------- ------------------------------- 0.9/4.1 MB 154.1 kB/s eta 0:00:22
#      -------- ------------------------------- 0.9/4.1 MB 154.1 kB/s eta 0:00:22
#      -------- ------------------------------- 0.9/4.1 MB 154.1 kB/s eta 0:00:22
#      -------- ------------------------------- 0.9/4.1 MB 152.6 kB/s eta 0:00:22
#      --------- ------------------------------ 1.0/4.1 MB 168.7 kB/s eta 0:00:19
#      --------- ------------------------------ 1.0/4.1 MB 168.7 kB/s eta 0:00:19
#      --------- ------------------------------ 1.0/4.1 MB 168.7 kB/s eta 0:00:19
#      --------- ------------------------------ 1.0/4.1 MB 168.7 kB/s eta 0:00:19
#      --------- ------------------------------ 1.0/4.1 MB 166.9 kB/s eta 0:00:19
#      --------- ------------------------------ 1.0/4.1 MB 166.9 kB/s eta 0:00:19
#      ---------- ----------------------------- 1.1/4.1 MB 185.0 kB/s eta 0:00:17
#      ---------- ----------------------------- 1.1/4.1 MB 185.0 kB/s eta 0:00:17
#      ---------- ----------------------------- 1.1/4.1 MB 185.0 kB/s eta 0:00:17
#      ---------- ----------------------------- 1.1/4.1 MB 185.0 kB/s eta 0:00:17
#      ----------- ---------------------------- 1.2/4.1 MB 184.4 kB/s eta 0:00:17
#      ------------ --------------------------- 1.3/4.1 MB 205.4 kB/s eta 0:00:14
#      ------------ --------------------------- 1.3/4.1 MB 205.4 kB/s eta 0:00:14
#      ------------ --------------------------- 1.3/4.1 MB 205.4 kB/s eta 0:00:14
#      ------------ --------------------------- 1.3/4.1 MB 205.4 kB/s eta 0:00:14
#      ------------ --------------------------- 1.3/4.1 MB 202.6 kB/s eta 0:00:14
#      ------------ --------------------------- 1.3/4.1 MB 202.6 kB/s eta 0:00:14
#      -------------- ------------------------- 1.5/4.1 MB 226.8 kB/s eta 0:00:12
#      -------------- ------------------------- 1.5/4.1 MB 226.8 kB/s eta 0:00:12
#      -------------- ------------------------- 1.5/4.1 MB 226.8 kB/s eta 0:00:12
#      -------------- ------------------------- 1.5/4.1 MB 226.8 kB/s eta 0:00:12
#      -------------- ------------------------- 1.5/4.1 MB 222.0 kB/s eta 0:00:12
#      ---------------- ----------------------- 1.7/4.1 MB 245.0 kB/s eta 0:00:10
#      ---------------- ----------------------- 1.7/4.1 MB 245.0 kB/s eta 0:00:10
#      ---------------- ----------------------- 1.7/4.1 MB 245.0 kB/s eta 0:00:10
#      ---------------- ----------------------- 1.7/4.1 MB 245.0 kB/s eta 0:00:10
#      ---------------- ----------------------- 1.7/4.1 MB 244.3 kB/s eta 0:00:10
#      ---------------- ----------------------- 1.7/4.1 MB 244.3 kB/s eta 0:00:10
#      ------------------ --------------------- 1.9/4.1 MB 268.2 kB/s eta 0:00:09
#      ------------------ --------------------- 1.9/4.1 MB 268.2 kB/s eta 0:00:09
#      ------------------ --------------------- 1.9/4.1 MB 268.2 kB/s eta 0:00:09
#      ------------------ --------------------- 1.9/4.1 MB 268.2 kB/s eta 0:00:09
#      ------------------ --------------------- 1.9/4.1 MB 266.9 kB/s eta 0:00:09
#      ------------------- -------------------- 2.0/4.1 MB 276.7 kB/s eta 0:00:08
#      --------------------- ------------------ 2.2/4.1 MB 294.8 kB/s eta 0:00:07
#      --------------------- ------------------ 2.2/4.1 MB 294.8 kB/s eta 0:00:07
#      --------------------- ------------------ 2.2/4.1 MB 294.8 kB/s eta 0:00:07
#      --------------------- ------------------ 2.2/4.1 MB 294.8 kB/s eta 0:00:07
#      --------------------- ------------------ 2.2/4.1 MB 291.6 kB/s eta 0:00:07
#      ----------------------- ---------------- 2.4/4.1 MB 321.6 kB/s eta 0:00:06
#      ----------------------- ---------------- 2.4/4.1 MB 321.6 kB/s eta 0:00:06
#      ----------------------- ---------------- 2.4/4.1 MB 321.6 kB/s eta 0:00:06
#      ----------------------- ---------------- 2.4/4.1 MB 321.6 kB/s eta 0:00:06
#      ------------------------ --------------- 2.5/4.1 MB 319.1 kB/s eta 0:00:06
#      -------------------------- ------------- 2.8/4.1 MB 351.2 kB/s eta 0:00:04
#      -------------------------- ------------- 2.8/4.1 MB 351.2 kB/s eta 0:00:04
#      -------------------------- ------------- 2.8/4.1 MB 351.2 kB/s eta 0:00:04
#      -------------------------- ------------- 2.8/4.1 MB 351.2 kB/s eta 0:00:04
#      --------------------------- ------------ 2.8/4.1 MB 346.8 kB/s eta 0:00:04
#      ------------------------------ --------- 3.1/4.1 MB 380.1 kB/s eta 0:00:03
#      ------------------------------ --------- 3.1/4.1 MB 380.1 kB/s eta 0:00:03
#      ------------------------------ --------- 3.1/4.1 MB 380.1 kB/s eta 0:00:03
#      ------------------------------ --------- 3.1/4.1 MB 380.1 kB/s eta 0:00:03
#      ------------------------------ --------- 3.1/4.1 MB 375.9 kB/s eta 0:00:03
#      ------------------------------ --------- 3.1/4.1 MB 375.9 kB/s eta 0:00:03
#      --------------------------------- ------ 3.5/4.1 MB 412.8 kB/s eta 0:00:02
#      --------------------------------- ------ 3.5/4.1 MB 412.8 kB/s eta 0:00:02
#      --------------------------------- ------ 3.5/4.1 MB 412.8 kB/s eta 0:00:02
#      --------------------------------- ------ 3.5/4.1 MB 412.8 kB/s eta 0:00:02
#      --------------------------------- ------ 3.5/4.1 MB 407.3 kB/s eta 0:00:02
#      ------------------------------------- -- 3.9/4.1 MB 446.4 kB/s eta 0:00:01
#      ------------------------------------- -- 3.9/4.1 MB 446.4 kB/s eta 0:00:01
#      ------------------------------------- -- 3.9/4.1 MB 446.4 kB/s eta 0:00:01
#      ------------------------------------- -- 3.9/4.1 MB 446.4 kB/s eta 0:00:01
#      ------------------------------------- -- 3.9/4.1 MB 440.4 kB/s eta 0:00:01
#      ------------------------------------- -- 3.9/4.1 MB 440.4 kB/s eta 0:00:01
#      ---------------------------------------- 4.1/4.1 MB 462.5 kB/s eta 0:00:00
# Requirement already satisfied: filelock in c:\users\raymond\anaconda3\envs\venv3.8\lib\site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\raymond\anaconda3\envs\venv3.8\lib\site-packages (from torch) (4.11.0)
# Requirement already satisfied: sympy in c:\users\raymond\anaconda3\envs\venv3.8\lib\site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in c:\users\raymond\anaconda3\envs\venv3.8\lib\site-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in c:\users\raymond\anaconda3\envs\venv3.8\lib\site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\raymond\anaconda3\envs\venv3.8\lib\site-packages (from torch) (2024.3.1)
# Requirement already satisfied: numpy in c:\users\raymond\anaconda3\envs\venv3.8\lib\site-packages (from torchvision) (1.24.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\raymond\anaconda3\envs\venv3.8\lib\site-packages (from torchvision) (10.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\raymond\anaconda3\envs\venv3.8\lib\site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in c:\users\raymond\anaconda3\envs\venv3.8\lib\site-packages (from sympy->torch) (1.3.0)
# Installing collected packages: torch, torchvision, torchaudio
# Successfully installed torch-2.4.1+cu124 torchaudio-2.4.1+cu124 torchvision-0.19.1+cu124

# %%
import torch

print(torch.__version__)
# Out:
# 2.4.1+cu124

# %%
import cv2
import numpy as np
import os
import torch
import torchvision.transforms as T

def adjust_contrast(image, alpha, beta):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    
    # Convert image to float32 and normalize to [0,1]
    image_tensor = torch.from_numpy(image).float().to(device) / 255.0
    
    # Apply contrast and brightness adjustment
    adjusted_tensor = torch.clamp(image_tensor * alpha + beta / 255.0, 0, 1)
    
    # Convert back to uint8 and return to CPU
    return (adjusted_tensor.cpu().numpy() * 255).astype(np.uint8)

def process_videos(input_folder, output_folder, alpha=1.5, beta=0):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    for filename in os.listdir(input_folder):
        if filename.endswith(('.mp4', '.avi', '.mov', '.mkv')):
            input_path = os.path.join(input_folder, filename)
            output_path = os.path.join(output_folder, filename)
            
            cap = cv2.VideoCapture(input_path)
            fourcc = cv2.VideoWriter_fourcc(*'mp4v')
            fps = int(cap.get(cv2.CAP_PROP_FPS))
            width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
            height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
            out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))
            
            while cap.isOpened():
                ret, frame = cap.read()
                if not ret:
                    break
                adjusted_frame = adjust_contrast(frame, alpha, beta)
                out.write(adjusted_frame)
            
            cap.release()
            out.release()
            print(f"Processed: {filename}")
    
    print("Processing complete.")

input_folder = "13"
output_folder = "output_13"
process_videos(input_folder, output_folder, alpha=1.8, beta=30) # Alpha = contrast, Beta = brightness
# Out:
# Processed: Video 15-028.mp4
# Processed: Video 15-029.mp4
# Processed: Video 15-030.mp4
# Processed: Video 15-031.mp4
# Processed: Video 15-032.mp4
# Processed: Video 15-033.mp4
# Processed: Video 15-034.mp4
# Processed: Video 15-035.mp4
# Processed: Video 15-036.mp4
# Processed: Video 15-037.mp4
# Processed: Video 15-038.mp4
# Processed: Video 15-039.mp4
# Processed: Video 15-040.mp4
# Processed: Video 15-041.mp4
# Processed: Video 15-042.mp4
# Processed: Video 15-043.mp4
# Processed: Video 15-044.mp4
# Processed: Video 15-045.mp4
# Processed: Video 15-046.mp4
# Processed: Video 15-047.mp4
# Processed: Video 15-048.mp4
# Processed: Video 15-049.mp4
# Processed: Video 15-050.mp4
# Processed: Video 15-051.mp4
# Processed: Video 15-052.mp4
# Processed: Video 15-053.mp4
# Processed: Video 15-054.mp4
# Processed: Video 15-055.mp4
# Processed: Video 15-056.mp4
# Processed: Video 15-057.mp4
# Processed: Video 15-058.mp4
# Processed: Video 15-059.mp4
# Processed: Video 15-060.mp4
# Processed: Video 15-061.mp4
# Processed: Video 15-062.mp4
# Processed: Video 15-063.mp4
# Processed: Video 15-064.mp4
# Processed: Video 15-065.mp4
# Processed: Video 15-066.mp4
# Processed: Video 15-067.mp4
# Processed: Video 15-068.mp4
# Processed: Video 15-069.mp4
# Processed: Video 15-070.mp4
# Processed: Video 15-071.mp4
# Processed: Video 15-072.mp4
# Processed: Video 15-073.mp4
# Processed: Video 15-074.mp4
# Processed: Video 15-075.mp4
# Processed: Video 15-076.mp4
# Processed: Video 15-077.mp4
# Processed: Video 15-078.mp4
# Processed: Video 15-079.mp4
# Processed: Video 15-080.mp4
# Processed: Video 15-081.mp4
# Processed: Video 15-082.mp4
# Processed: Video 15-083.mp4
# Processed: Video 15-084.mp4
# Processed: Video 15-085.mp4
# Processed: Video 15-086.mp4
# Processed: Video 15-087.mp4
# Processed: Video 15-088.mp4
# Processed: Video 15-089.mp4
# Processed: Video 15-090.mp4
# Processed: Video 15-091.mp4
# Processed: Video 15-092.mp4
# Processed: Video 15-093.mp4
# Processed: Video 15-094.mp4
# Processed: Video 15-095.mp4
# Processed: Video 15-096.mp4
# Processed: Video 15-097.mp4
# Processed: Video 15-098.mp4
# Processed: Video 15-099.mp4
# Processed: Video 15-100.mp4
# Processed: Video 15-101.mp4
# Processed: Video 15-102.mp4
# Processed: Video 15-103.mp4
# Processed: Video 15-104.mp4
# Processed: Video 15-105.mp4
# Processed: Video 15-106.mp4
# Processed: Video 15-107.mp4
# Processed: Video 15-108.mp4
# Processed: Video 15-109.mp4
# Processed: Video 15-110.mp4
# Processed: Video 15-111.mp4
# Processed: Video 15-112.mp4
# Processed: Video 15-113.mp4
# Processed: Video 15-114.mp4
# Processed: Video 15-115.mp4
# Processed: Video 15-116.mp4
# Processed: Video 15-117.mp4
# Processed: Video 15-118.mp4
# Processed: Video 15-119.mp4
# Processed: Video 15-120.mp4
# Processed: Video 15-121.mp4
# Processed: Video 15-122.mp4
# Processed: Video 15-123.mp4
# Processed: Video 15-124.mp4
# Processing complete.

# %%
#Rename the videos (has subfolders) with the folder name

import os

def rename_videos_with_folder_name(base_folder):
    for subfolder in os.listdir(base_folder):
        subfolder_path = os.path.join(base_folder, subfolder)
        if os.path.isdir(subfolder_path):
            for idx, filename in enumerate(os.listdir(subfolder_path)):
                input_path = os.path.join(subfolder_path, filename)
                if os.path.isfile(input_path) and filename.lower().endswith(".mp4"):
                    new_filename = f"{subfolder}{idx+1:03d}.mp4"
                    new_path = os.path.join(subfolder_path, new_filename)
                    os.rename(input_path, new_path)
                    print(f"Renamed: {filename} -> {new_filename}")

if __name__ == "__main__":
    base_folder = "reduced_videos2" 
    rename_videos_with_folder_name(base_folder)
# Out:
# Renamed: 37(side).mp4 -> Grazing001.mp4
# Renamed: 38(front).mp4 -> Grazing002.mp4
# Renamed: 38(side).mp4 -> Grazing003.mp4
# Renamed: 39(front).mp4 -> Grazing004.mp4
# Renamed: 39(side).mp4 -> Grazing005.mp4
# Renamed: 038 (run side).mp4 -> Running001.mp4
# Renamed: 039 (run side).mp4 -> Running002.mp4
# Renamed: 040 (run side).mp4 -> Running003.mp4
# Renamed: 041 (run side).mp4 -> Running004.mp4
# Renamed: IMG_5483(0).mp4 -> Running005.mp4
# Renamed: 025(sit side).mp4 -> Sitting001.mp4
# Renamed: 027(sit front).mp4 -> Sitting002.mp4
# Renamed: 028(sit front).mp4 -> Sitting003.mp4
# Renamed: 032(sit front).mp4 -> Sitting004.mp4
# Renamed: IMG_5320.mp4 -> Sitting005.mp4

# %%
# Make csv for labels (has sub folders)

import os
import csv

def label_dataset(root_dir, output_csv):
    with open(output_csv, mode='w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(["video_name", "tag"])
        
        for category in os.listdir(root_dir):
            category_path = os.path.join(root_dir, category)
            if os.path.isdir(category_path):
                for video in os.listdir(category_path):
                    video_path = os.path.join(category, video)  # Relative path
                    writer.writerow([video_path, category])

if __name__ == "__main__":
    dataset_folder = "Grazing_Running_Sitting Sheep_Classes"  # Folder containing the videos
    output_file = "Grazing_Running_Sitting Sheep_Classes/train.csv"
    label_dataset(dataset_folder, output_file)
    print(f"CSV file '{output_file}' created successfully.")
# Out:
# CSV file 'Grazing_Running_Sitting Sheep_Classes/train.csv' created successfully.

# %%
# Move out the videos from subfolders to main folder

import os
import shutil

def move_videos_to_main_folder(base_folder):
    for subfolder in os.listdir(base_folder):
        subfolder_path = os.path.join(base_folder, subfolder)
        if os.path.isdir(subfolder_path):
            for filename in os.listdir(subfolder_path):
                input_path = os.path.join(subfolder_path, filename)
                if os.path.isfile(input_path) and filename.lower().endswith(".mp4"):
                    new_path = os.path.join(base_folder, filename)
                    shutil.move(input_path, new_path)
                    print(f"Moved: {filename} -> {base_folder}")

if __name__ == "__main__":
    base_folder = "D:\Recordings\Cleaned Videos\Video Split - Copy"  # Base folder containing the videos
    move_videos_to_main_folder(base_folder)
# Out:
# Moved: Video 01-001.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 01-002.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 01-003.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 01-005.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 01-006.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 01-007.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 01-008.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 01-009.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 01-010.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 01-011.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 01-012.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 01-014.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 01-015.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 01-016.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 01-017.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 01-018.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 01-019.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 01-020.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 01-021.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 01-022.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 01-023.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 01-024.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 01-025.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 01-026.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 01-027.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 01-028.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 01-029.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 01-030.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 01-031.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 01-032.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 01-033.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 01-034.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 01-035.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 01-036.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 01-037.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 01-038.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 01-039.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 01-040.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 01-041.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 01-042.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 01-043.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 01-044.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 01-045.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 01-046.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 01-047.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 01-048.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 01-049.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 01-050.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 01-051.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 01-052.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 01-053.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 01-054.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 01-055.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-002.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-003.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-004.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-005.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-006.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-022.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-023.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-024.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-025.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-026.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-027.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-028.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-029.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-030.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-031.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-032.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-033.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-034.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-035.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-036.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-037.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-038.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-039.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-040.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-041.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-042.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-043.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-044.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-045.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-046.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-047.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-048.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-049.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-050.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-051.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-052.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-053.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-054.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-055.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-056.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-057.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-058.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-059.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-060.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-061.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-062.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-063.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-064.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-065.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-066.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-067.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-068.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-069.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-070.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-071.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-072.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-073.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-074.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-075.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-076.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-077.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-078.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-079.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-080.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-081.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-082.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-083.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-084.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-085.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-086.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-087.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-088.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-089.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-090.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-091.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-092.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-093.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-094.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-095.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-096.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-097.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-098.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-099.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-100.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-101.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-102.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-103.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-104.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-105.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-106.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-107.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-108.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-109.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-110.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-111.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-112.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-113.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-114.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-115.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-116.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-117.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-118.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 02-132.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-252.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-253.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-254.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-255.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-256.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-257.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-258.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-259.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-260.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-261.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-262.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-263.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-264.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-265.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-266.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-267.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-268.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-269.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-270.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-273.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-274.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-275.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-276.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-278.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-279.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-280.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-281.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-282.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-283.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-284.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-285.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-286.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-287.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-011.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-012.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-013.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-014.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-016.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-017.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-026.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-027.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-028.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-029.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-030.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-031.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-032.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-033.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-034.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-035.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-036.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-037.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-038.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-039.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-040.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-041.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-050.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-051.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-052.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-053.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-054.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-055.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-056.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-057.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-058.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-059.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-062.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-063.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-064.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-065.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-066.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-067.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-068.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-069.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-070.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-071.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-072.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-073.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-074.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-075.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-076.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-077.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-078.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-079.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-080.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-081.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-084.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-085.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-086.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-087.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-088.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-089.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-090.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-095.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-096.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-097.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-098.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-099.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-100.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-101.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-102.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-103.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-104.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-105.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-106.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-107.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-108.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-109.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-110.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-111.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-112.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-113.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-114.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-115.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-118.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-119.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-120.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-121.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-122.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-123.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-124.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-127.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-128.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-129.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-130.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-131.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-132.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-133.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-134.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-135.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-136.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-137.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-138.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-139.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-140.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-141.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-142.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-143.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-144.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-147.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-148.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-149.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-150.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-151.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-152.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-153.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-154.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-155.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-156.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-157.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-158.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-159.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-160.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-161.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-162.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-163.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-164.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-165.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-166.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-167.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-168.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-169.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-170.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-171.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-172.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-173.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-174.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-175.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-176.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-177.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-178.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-179.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-180.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-181.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-182.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-183.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-184.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-185.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-186.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-187.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-188.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-189.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-190.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-191.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-192.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-193.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-194.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-195.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-196.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-197.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-198.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-199.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-200.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-201.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-202.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-203.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-204.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-205.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-206.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-207.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-208.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-209.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-210.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-211.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-212.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-213.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-214.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-215.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-216.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-217.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-218.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-219.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-220.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-221.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-223.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-224.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-225.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-226.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-227.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-228.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-229.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-230.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-231.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-232.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-233.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-234.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-235.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-236.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-237.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-239.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-240.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-241.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-242.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-243.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-244.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-245.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-246.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-247.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-248.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-249.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-250.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-251.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-252.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-253.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-254.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-255.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-256.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-257.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-258.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-259.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-260.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-261.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-262.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-263.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-264.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-265.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-266.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-267.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-268.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-269.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-270.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-271.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-272.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-273.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-274.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-275.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-276.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-277.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-278.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-279.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-280.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-281.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-282.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-283.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-284.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-285.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-286.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-287.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-290.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 13-291.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-009.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-010.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-011.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-012.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-013.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-015.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-016.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-017.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-018.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-024.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-026.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-028.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-029.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-030.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-031.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-032.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-033.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-035.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-036.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-037.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-038.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-039.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-040.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-041.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-043.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-044.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-047.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-049.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-050.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-051.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-052.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-053.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-054.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-055.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-056.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-057.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-058.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-059.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-060.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-061.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-062.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-063.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-064.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-065.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-066.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-067.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-068.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-069.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-070.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-071.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-072.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-073.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-074.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-075.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-076.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-077.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-078.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-079.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-080.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-081.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-082.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-083.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-084.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-086.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-094.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-095.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-096.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-097.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-098.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-099.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-100.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-101.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-102.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-104.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-105.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-106.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-107.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-108.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-109.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-110.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-111.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-112.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-113.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-114.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-115.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-116.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-117.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-118.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-119.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-121.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-122.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-123.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-124.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-125.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-127.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-128.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-129.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-130.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-131.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-132.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-133.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-134.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-135.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-136.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-137.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-138.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-139.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-140.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-141.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-142.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-143.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-144.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-145.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-146.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-147.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-148.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-149.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-150.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-151.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-152.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-153.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-154.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-155.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-156.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-157.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-158.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-159.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-160.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-161.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-162.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-163.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-164.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-165.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-166.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-167.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-168.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-169.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-170.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-171.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-172.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-173.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-174.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-175.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-176.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-177.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-178.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-179.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-180.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-181.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-182.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-183.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-184.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-185.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-186.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-187.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-188.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-189.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-190.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-191.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-192.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-193.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-194.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-195.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-196.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-197.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-198.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-199.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-200.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-201.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-202.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-203.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-204.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-205.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-206.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-207.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-208.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-209.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-210.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-211.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-212.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-213.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-214.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-215.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-216.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-217.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-218.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-219.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-220.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-233.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-234.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-235.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-236.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-237.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-238.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-239.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-240.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-241.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-242.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-243.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-244.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-245.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-246.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-247.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-248.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 14-249.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# ...
# Moved: Video 11-146.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 11-147.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 11-148.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 11-149.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 11-150.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 11-151.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 11-152.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 11-153.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 11-154.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 11-155.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 11-156.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 11-157.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 11-158.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 11-159.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 11-160.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 11-161.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 11-162.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 11-163.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 11-164.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 11-165.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 11-167.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 11-168.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 11-169.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-017.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-018.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-019.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-021.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-022.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-023.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-024.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-025.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-026.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-027.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-028.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-029.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-030.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-031.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-032.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-033.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-039.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-040.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-041.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-042.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-043.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-044.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-045.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-050.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-051.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-053.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-054.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-055.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-056.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-057.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-058.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-059.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-060.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-061.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-062.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-063.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-064.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-091.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-092.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-093.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-094.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-095.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-096.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-097.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-098.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-099.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-100.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-101.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-102.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-103.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-104.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-105.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-106.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-107.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-108.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-109.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-110.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-111.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-112.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-114.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-115.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-116.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-117.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-119.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-120.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-121.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-122.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-123.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-124.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-125.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-126.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-128.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-129.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-130.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-131.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-132.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-133.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-134.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-135.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-136.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-137.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-138.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-139.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-140.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-141.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-142.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-143.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-144.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-145.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-146.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-147.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-148.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-149.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-150.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-151.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-152.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-153.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-154.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-155.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-156.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-157.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-158.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-159.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-160.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-161.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-162.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-163.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-164.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-165.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-166.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-167.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-168.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-169.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-170.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-171.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-172.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-173.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-174.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-175.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-176.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-177.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-178.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-179.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-180.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-181.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-182.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-183.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-184.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-185.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-186.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-187.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-188.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-189.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-190.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-191.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-192.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-193.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-194.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-195.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-196.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-197.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-198.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-199.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-200.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-201.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-202.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-203.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-204.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-205.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-206.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-207.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-208.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-209.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-210.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-211.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-212.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-213.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-214.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-215.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-216.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-217.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-218.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-219.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-220.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-221.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-222.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-224.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-226.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-227.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-228.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-229.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-230.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-233.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-234.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-235.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-236.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-237.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-238.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-239.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-240.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-241.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-242.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-243.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-244.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-246.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-247.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-248.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-249.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-250.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy
# Moved: Video 12-251.mp4 -> D:\Recordings\Cleaned Videos\Video Split - Copy

# %%
# Make csv for labels (no sub folders)

import os
import csv

# Folder containing the video files
folder_path = "SheepTest copy"  # Change this to your actual folder path
output_csv = "SheepTest copy/test.csv"

# Get all video files in the folder
video_files = [f for f in os.listdir(folder_path) if f.endswith(".mp4")]

# Extract tags from filenames
data = []
for video in video_files:
    tag = "".join(filter(str.isalpha, video.rsplit(".", 1)[0]))  # Extract the alphabetic part as tag
    data.append([video, tag])

# Write to CSV
with open(output_csv, "w", newline="") as file:
    writer = csv.writer(file)
    writer.writerow(["video_name", "tag"])
    writer.writerows(data)

print(f"CSV file '{output_csv}' has been created.")
# Out:
# CSV file 'SheepTest copy/test.csv' has been created.

# %%
import os
import random
import csv
import subprocess

# Define test set directory
test_dir = r"Goat\Test"

# Get all video files
video_files = []
for root, _, files in os.walk(test_dir):
    for file in files:
        if file.endswith(".mp4"):
            video_files.append(os.path.join(root, file))

# Shuffle video order randomly
random.shuffle(video_files)

# Create a text file list for ffmpeg
ffmpeg_list_file = "video_list.txt"
with open(ffmpeg_list_file, "w") as f:
    for video in video_files:
        f.write(f"file '{video}'\n")

# Generate CSV file
csv_file = "stitched_videos.csv"
start_time = 0
with open(csv_file, "w", newline="") as csvfile:
    csv_writer = csv.writer(csvfile)
    csv_writer.writerow(["video_path", "start_time", "end_time"])
    
    for video in video_files:
        duration_cmd = f'ffprobe -i "{video}" -show_entries format=duration -v quiet -of csv="p=0"'
        duration = float(subprocess.check_output(duration_cmd, shell=True).decode().strip())

        end_time = start_time + duration
        csv_writer.writerow([video, f"{start_time:.2f}", f"{end_time:.2f}"])
        start_time = end_time

# Use ffmpeg to stitch videos together
output_video = "stitched_output.mp4"
concat_cmd = f'ffmpeg -f concat -safe 0 -i {ffmpeg_list_file} -c copy {output_video}'
subprocess.run(concat_cmd, shell=True)

print(f"Stitched video saved as {output_video}")
print(f"CSV metadata saved as {csv_file}")
# Out:
# Stitched video saved as stitched_output.mp4
# CSV metadata saved as stitched_videos.csv

# %%
import cv2
import numpy as np
import tensorflow as tf
from sklearn.preprocessing import LabelEncoder
import time

def predict_real_time(video_path, model, encoder, window_size=30, stride=8, img_size=(64, 64), interval=5):
    """
    Predicts actions from a video stream in real-time every `interval` seconds.

    Args:
        video_path (str): Path to the video file.
        model (tf.keras.Model): Trained 3D CNN model.
        encoder (LabelEncoder): Encoder for decoding class labels.
        window_size (int): Number of frames per prediction window.
        stride (int): Number of frames to move between windows.
        img_size (tuple): Resize dimensions for frames.
        interval (int): Time interval (in seconds) for predictions.
    """
    cap = cv2.VideoCapture(video_path)
    fps = cap.get(cv2.CAP_PROP_FPS)
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    frame_buffer = []
    frame_idx = 0
    last_pred_time = time.time()
    
    print(f"Processing video: {video_path}")
    print(f"Total frames: {total_frames}, FPS: {fps}")
    
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break
        
        # Resize and normalize frame
        frame = cv2.resize(frame, img_size)
        frame = frame / 255.0
        frame_buffer.append(frame)
        
        # Predict every `interval` seconds
        if time.time() - last_pred_time >= interval:
            if len(frame_buffer) >= window_size:
                input_data = np.expand_dims(np.array(frame_buffer[-window_size:]), axis=0)  # Last `window_size` frames
                pred = model.predict(input_data, verbose=0)
                class_idx = np.argmax(pred)
                predicted_label = encoder.inverse_transform([class_idx])[0]

                # Display prediction with timestamp
                timestamp = frame_idx / fps
                minutes = int(timestamp // 60)
                seconds = int(timestamp % 60)
                print(f"[{minutes:02d}:{seconds:02d}] Predicted Action: {predicted_label}")

                last_pred_time = time.time()
        
        frame_idx += 1
    
    cap.release()

# Load saved model
model = tf.keras.models.load_model("goat_action_3dcnn-30frames.h5")

# Initialize encoder with class labels
CLASSES = ['Running', 'Sitting', 'Grazing']
encoder = LabelEncoder()
encoder.fit(CLASSES)

# Path to long video
video_path = r"stitched_output.mp4"

# Predict actions in real-time every 5 seconds
predict_real_time(video_path, model, encoder, window_size=30, stride=8, img_size=(64, 64), interval=5)
# Out:
# Processing video: stitched_output.mp4
# Total frames: 4540, FPS: 41.91179785039039
# [00:06] Predicted Action: Grazing
# [00:13] Predicted Action: Grazing
# [00:20] Predicted Action: Grazing
# [00:28] Predicted Action: Grazing
# [00:35] Predicted Action: Grazing
# [00:43] Predicted Action: Grazing
# [00:50] Predicted Action: Grazing
# [00:56] Predicted Action: Running
# [01:02] Predicted Action: Sitting
# [01:08] Predicted Action: Sitting
# [01:13] Predicted Action: Sitting
# [01:20] Predicted Action: Grazing
# [01:27] Predicted Action: Grazing
# [01:34] Predicted Action: Grazing
# [01:41] Predicted Action: Grazing

# %%
# Count the number of videos in a folder and its subfolders

import os

def count_videos_in_folder(base_folder):
    video_extensions = ('.mp4', '.avi', '.mov', '.mkv')
    video_count = 0
    
    for root, _, files in os.walk(base_folder):
        for file in files:
            if file.lower().endswith(video_extensions):
                video_count += 1
    
    return video_count

base_folder = r"D:\Recordings\Cleaned Videos\Segmented Videos" 
total_videos = count_videos_in_folder(base_folder)
print(f"Total number of videos: {total_videos}")
# Out:
# Total number of videos: 3470

# %%
import os

def count_videos_in_subfolders(base_folder):
    video_extensions = ('.mp4', '.avi', '.mov', '.mkv')
    subfolder_video_counts = {}
    
    for subfolder in os.listdir(base_folder):
        subfolder_path = os.path.join(base_folder, subfolder)
        if os.path.isdir(subfolder_path):
            video_count = 0
            for root, _, files in os.walk(subfolder_path):
                for file in files:
                    if file.lower().endswith(video_extensions):
                        video_count += 1
            subfolder_video_counts[subfolder] = video_count
    
    return subfolder_video_counts

base_folder = r"C:\Users\Raymond\Downloads\Segmented Videos - Maam Jas"  # Change this to your actual folder path
video_counts = count_videos_in_subfolders(base_folder)
for subfolder, count in video_counts.items():
    print(f"{subfolder}: {count} videos")
# Out:
# Module 1: 156 videos
# Module 10: 174 videos
# Module 11: 184 videos
# Module 12: 176 videos
# Module 13: 165 videos
# Module 14: 164 videos
# Module 15: 193 videos
# Module 16: 160 videos
# Module 17: 208 videos
# Module 18: 201 videos
# Module 19: 209 videos
# Module 2: 69 videos
# Module 20: 180 videos
# Module 3: 148 videos
# Module 4: 170 videos
# Module 5: 187 videos
# module 6: 209 videos
# Module 7: 185 videos
# Module 8: 158 videos
# Module 9: 174 videos
